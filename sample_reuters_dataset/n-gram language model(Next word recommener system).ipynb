# %% [markdown]
# Steps to build the next word recommender system
# Loading and exploring the dataset
# Creating N-grams of the dialogue
# Building the N-gram Language Model
# Predicting the next word using N-gram Language Model

# %%
# loading the required libraries
import pandas as pd
import numpy as np
import re
import pickle
import random
from tqdm import tqdm

# %%
# open text file and read in data
df = pd.read_csv("sample_reuters_dataset.csv")

# %%
df.head()
# Out:
#    sentence_number                                      sentence_text
# 0                0  ASIAN EXPORTERS FEAR DAMAGE FROM U . S .- JAPA...
# 1                1  They told Reuter correspondents in Asian capit...
# 2                2  But some exporters said that while the conflic...
# 3                3  The U . S . Has said it will impose 300 mln dl...
# 4                4  Unofficial Japanese estimates put the impact o...

# %%
import re
import string

# Convert text to lowercase
df['cleaned_text'] = df['sentence_text'].apply(lambda x: x.lower())

# Removing punctuation
df['cleaned_text'] = df['cleaned_text'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))

# Removing special characters
df['cleaned_text'] = df['cleaned_text'].apply(lambda x: re.sub(r'[^a-zA-Z\s]', '', x))

# Display the cleaned and tokenized dataset
print(df.head())
# Out:
#    sentence_number                                      sentence_text  \
# 0                0  ASIAN EXPORTERS FEAR DAMAGE FROM U . S .- JAPA...
# 1                1  They told Reuter correspondents in Asian capit...
# 2                2  But some exporters said that while the conflic...
# 3                3  The U . S . Has said it will impose 300 mln dl...
# 4                4  Unofficial Japanese estimates put the impact o...
#
#                                         cleaned_text
# 0  asian exporters fear damage from u  s  japan r...
# 1  they told reuter correspondents in asian capit...
# 2  but some exporters said that while the conflic...
# 3  the u  s  has said it will impose  mln dlrs of...
# 4  unofficial japanese estimates put the impact o...

# %%
import nltk
from nltk.tokenize import word_tokenize

# %%
 df['cleaned_text']
# Out:
# 0       asian exporters fear damage from u  s  japan r...
# 1       they told reuter correspondents in asian capit...
# 2       but some exporters said that while the conflic...
# 3       the u  s  has said it will impose  mln dlrs of...
# 4       unofficial japanese estimates put the impact o...
#                               ...
# 9995    in addition  british printing and communicatio...
# 9996    salomon said in a filing with the securities a...
# 9997    if the court decides they should be converted ...
# 9998    harcourt is asking the court to rule the compa...
# 9999    an increase in reed shares in london today was...
# Name: cleaned_text, Length: 10000, dtype: object

# %%
# Tokenization
df['tokenized_text'] = df['cleaned_text'].apply(word_tokenize)

# %%
df['tokenized_text']
# Out:
# 0       [asian, exporters, fear, damage, from, u, s, j...
# 1       [they, told, reuter, correspondents, in, asian...
# 2       [but, some, exporters, said, that, while, the,...
# 3       [the, u, s, has, said, it, will, impose, mln, ...
# 4       [unofficial, japanese, estimates, put, the, im...
#                               ...
# 9995    [in, addition, british, printing, and, communi...
# 9996    [salomon, said, in, a, filing, with, the, secu...
# 9997    [if, the, court, decides, they, should, be, co...
# 9998    [harcourt, is, asking, the, court, to, rule, t...
# 9999    [an, increase, in, reed, shares, in, london, t...
# Name: tokenized_text, Length: 10000, dtype: object

# %%
# Create vocabulary
vocabulary = set()
for tokenized_sentence in df['tokenized_text']:
    vocabulary.update(tokenized_sentence)

# %%
# function to create unigrams
# taking a sentence as input
def create_unigram(sentence):
    # creating tokens from the sentence
    tokens = sentence.split()
    # empty list to store the unigrams
    unigram_list = []
    # number of unigrams is equal to the number of tokens in the sentence
    for i in range(len(tokens)):
        # appending each unigram in the list
        unigram_list.append(tokens[i:i+1])
    # returning the unigram list for a sentence    
    return unigram_list

# %%
# function to create bigrams
def create_bigram(sentence):
    tokens = sentence.split()
    bigram_list = []
    # number of bigrams is one less than the number of tokens in the sentence
    for i in range(len(tokens)-1):
        bigram_list.append(tokens[i:i+2])
    return bigram_list

# %%
# function to create trigrams
def create_trigram(sentence):
    tokens = sentence.split()
    trigram_list = []
    # number of trigrams is two less than the number of tokens in the sentence
    for i in range(len(tokens)-2):
        trigram_list.append(tokens[i:i+3])
    return trigram_list

# %%
# creating unigrams for all the sentences in the dataset 
final_unigram = []
# for each sentence
for i in range(df.shape[0]):
    # using the defined unigram function to create unigrams
    final_unigram.append(create_unigram( df['cleaned_text'][i]))

# adding the unigram in a seperate column in the dataset
df['unigram'] = final_unigram

# %%
# creating bigrams for all the sentences in the dataset
final_bigram = []
for i in range(df.shape[0]):
    final_bigram.append(create_bigram(df['cleaned_text'][i]))

df['bigram'] = final_bigram

# %%
# creating trigrams for all the sentences in the dataset
final_trigram = []
for i in range(df.shape[0]):
    final_trigram.append(create_trigram(df['cleaned_text'][i]))

df['trigram'] = final_trigram

# %%
df.head(20)
# Out:
#     sentence_number                                      sentence_text  \
# 0                 0  ASIAN EXPORTERS FEAR DAMAGE FROM U . S .- JAPA...
# 1                 1  They told Reuter correspondents in Asian capit...
# 2                 2  But some exporters said that while the conflic...
# 3                 3  The U . S . Has said it will impose 300 mln dl...
# 4                 4  Unofficial Japanese estimates put the impact o...
# 5                 5  " We wouldn ' t be able to do business ," said...
# 6                 6  " If the tariffs remain in place for any lengt...
# 7                 7  In Taiwan , businessmen and officials are also...
# 8                 8   " We are aware of the seriousness of the U . S .
# 9                 9  Threat against Japan because it serves as a wa...
# 10               10  Taiwan had a trade trade surplus of 15 . 6 bil...
# 11               11  The surplus helped swell Taiwan ' s foreign ex...
# 12               12  " We must quickly open our markets , remove tr...
# 13               13  Retaliation ," said Paul Sheen , chairman of t...
# 14               14  A senior official of South Korea ' s trade pro...
# 15               15  Last year South Korea had a trade surplus of 7...
# 16               16  In Malaysia , trade officers and businessmen s...
# 17               17  In Hong Kong , where newspapers have alleged J...
# 18               18  But other businessmen said such a short - term...
# 19               19  " That is a very short - term view ," said Law...
#
#                                          cleaned_text  \
# 0   asian exporters fear damage from u  s  japan r...
# 1   they told reuter correspondents in asian capit...
# 2   but some exporters said that while the conflic...
# 3   the u  s  has said it will impose  mln dlrs of...
# 4   unofficial japanese estimates put the impact o...
# 5    we wouldn  t be able to do business  said a s...
# 6    if the tariffs remain in place for any length...
# 7   in taiwan  businessmen and officials are also ...
# 8        we are aware of the seriousness of the u  s
# 9   threat against japan because it serves as a wa...
# 10  taiwan had a trade trade surplus of    billion...
# 11  the surplus helped swell taiwan  s foreign exc...
# 12   we must quickly open our markets  remove trad...
# 13  retaliation  said paul sheen  chairman of text...
# 14  a senior official of south korea  s trade prom...
# 15  last year south korea had a trade surplus of  ...
# 16  in malaysia  trade officers and businessmen sa...
# 17  in hong kong  where newspapers have alleged ja...
# 18  but other businessmen said such a short  term ...
# 19   that is a very short  term view  said lawrenc...
#
#                                        tokenized_text  \
# 0   [asian, exporters, fear, damage, from, u, s, j...
# 1   [they, told, reuter, correspondents, in, asian...
# 2   [but, some, exporters, said, that, while, the,...
# 3   [the, u, s, has, said, it, will, impose, mln, ...
# 4   [unofficial, japanese, estimates, put, the, im...
# 5   [we, wouldn, t, be, able, to, do, business, sa...
# 6   [if, the, tariffs, remain, in, place, for, any...
# 7   [in, taiwan, businessmen, and, officials, are,...
# 8   [we, are, aware, of, the, seriousness, of, the...
# 9   [threat, against, japan, because, it, serves, ...
# 10  [taiwan, had, a, trade, trade, surplus, of, bi...
# 11  [the, surplus, helped, swell, taiwan, s, forei...
# 12  [we, must, quickly, open, our, markets, remove...
# 13  [retaliation, said, paul, sheen, chairman, of,...
# 14  [a, senior, official, of, south, korea, s, tra...
# 15  [last, year, south, korea, had, a, trade, surp...
# 16  [in, malaysia, trade, officers, and, businessm...
# 17  [in, hong, kong, where, newspapers, have, alle...
# 18  [but, other, businessmen, said, such, a, short...
# 19  [that, is, a, very, short, term, view, said, l...
#
#                                               unigram  \
# 0   [[asian], [exporters], [fear], [damage], [from...
# 1   [[they], [told], [reuter], [correspondents], [...
# 2   [[but], [some], [exporters], [said], [that], [...
# 3   [[the], [u], [s], [has], [said], [it], [will],...
# 4   [[unofficial], [japanese], [estimates], [put],...
# 5   [[we], [wouldn], [t], [be], [able], [to], [do]...
# 6   [[if], [the], [tariffs], [remain], [in], [plac...
# 7   [[in], [taiwan], [businessmen], [and], [offici...
# 8   [[we], [are], [aware], [of], [the], [seriousne...
# 9   [[threat], [against], [japan], [because], [it]...
# 10  [[taiwan], [had], [a], [trade], [trade], [surp...
# 11  [[the], [surplus], [helped], [swell], [taiwan]...
# 12  [[we], [must], [quickly], [open], [our], [mark...
# 13  [[retaliation], [said], [paul], [sheen], [chai...
# 14  [[a], [senior], [official], [of], [south], [ko...
# 15  [[last], [year], [south], [korea], [had], [a],...
# 16  [[in], [malaysia], [trade], [officers], [and],...
# 17  [[in], [hong], [kong], [where], [newspapers], ...
# 18  [[but], [other], [businessmen], [said], [such]...
# 19  [[that], [is], [a], [very], [short], [term], [...
#
#                                                bigram  \
# 0   [[asian, exporters], [exporters, fear], [fear,...
# 1   [[they, told], [told, reuter], [reuter, corres...
# 2   [[but, some], [some, exporters], [exporters, s...
# 3   [[the, u], [u, s], [s, has], [has, said], [sai...
# 4   [[unofficial, japanese], [japanese, estimates]...
# 5   [[we, wouldn], [wouldn, t], [t, be], [be, able...
# 6   [[if, the], [the, tariffs], [tariffs, remain],...
# 7   [[in, taiwan], [taiwan, businessmen], [busines...
# 8   [[we, are], [are, aware], [aware, of], [of, th...
# 9   [[threat, against], [against, japan], [japan, ...
# 10  [[taiwan, had], [had, a], [a, trade], [trade, ...
# 11  [[the, surplus], [surplus, helped], [helped, s...
# 12  [[we, must], [must, quickly], [quickly, open],...
# 13  [[retaliation, said], [said, paul], [paul, she...
# 14  [[a, senior], [senior, official], [official, o...
# 15  [[last, year], [year, south], [south, korea], ...
# 16  [[in, malaysia], [malaysia, trade], [trade, of...
# 17  [[in, hong], [hong, kong], [kong, where], [whe...
# 18  [[but, other], [other, businessmen], [business...
# 19  [[that, is], [is, a], [a, very], [very, short]...
#
#                                               trigram
# 0   [[asian, exporters, fear], [exporters, fear, d...
# 1   [[they, told, reuter], [told, reuter, correspo...
# 2   [[but, some, exporters], [some, exporters, sai...
# 3   [[the, u, s], [u, s, has], [s, has, said], [ha...
# 4   [[unofficial, japanese, estimates], [japanese,...
# 5   [[we, wouldn, t], [wouldn, t, be], [t, be, abl...
# 6   [[if, the, tariffs], [the, tariffs, remain], [...
# 7   [[in, taiwan, businessmen], [taiwan, businessm...
# 8   [[we, are, aware], [are, aware, of], [aware, o...
# 9   [[threat, against, japan], [against, japan, be...
# 10  [[taiwan, had, a], [had, a, trade], [a, trade,...
# 11  [[the, surplus, helped], [surplus, helped, swe...
# 12  [[we, must, quickly], [must, quickly, open], [...
# 13  [[retaliation, said, paul], [said, paul, sheen...
# 14  [[a, senior, official], [senior, official, of]...
# 15  [[last, year, south], [year, south, korea], [s...
# 16  [[in, malaysia, trade], [malaysia, trade, offi...
# 17  [[in, hong, kong], [hong, kong, where], [kong,...
# 18  [[but, other, businessmen], [other, businessme...
# 19  [[that, is, a], [is, a, very], [a, very, short...

# %%
# unigram of the sentence
df['unigram'][0]
# Out:
# [['asian'],
#  ['exporters'],
#  ['fear'],
#  ['damage'],
#  ['from'],
#  ['u'],
#  ['s'],
#  ['japan'],
#  ['rift'],
#  ['mounting'],
#  ['trade'],
#  ['friction'],
#  ['between'],
#  ['the'],
#  ['u'],
#  ['s'],
#  ['and'],
#  ['japan'],
#  ['has'],
#  ['raised'],
#  ['fears'],
#  ['among'],
#  ['many'],
#  ['of'],
#  ['asia'],
#  ['s'],
#  ['exporting'],
#  ['nations'],
#  ['that'],
#  ['the'],
#  ['row'],
#  ['could'],
#  ['inflict'],
#  ['far'],
#  ['reaching'],
#  ['economic'],
#  ['damage'],
#  ['businessmen'],
#  ['and'],
#  ['officials'],
#  ['said']]

# %%
# for defining the N-gram model
from collections import Counter, defaultdict

# Create a placeholder for model
model = defaultdict(lambda: defaultdict(lambda: 0))

# Count frequency of co-occurance  
for i in range(df.shape[0]):
    # for each trigram pair
    for w1, w2, w3 in create_trigram(df['cleaned_text'][i]):
        # count the occurance of word 3, given word 1 and word 2
        model[(w1, w2)][w3] += 1

# %%
# defined model
model
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {('asian',
#               'exporters'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'fear': 1}),
#              ('exporters',
#               'fear'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'damage': 1}),
#              ('fear',
#               'damage'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'from': 1}),
#              ('damage',
#               'from'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'u': 1, 'local': 1}),
#              ('from',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'s': 5, 'k': 1}),
#              ('u',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'japan': 6,
#                           'and': 34,
#                           'move': 1,
#                           'has': 7,
#                           'said': 4,
#                           'products': 5,
#                           'up': 2,
#                           'pressure': 3,
#                           'last': 5,
#                           'exports': 8,
#                           'japanese': 5,
#                           'trade': 44,
#                           'department': 3,
#                           'dlrs': 36,
#                           'securities': 2,
#                           'glass': 1,
#                           'commercial': 1,
#                           'officials': 30,
#                           'farm': 6,
#                           'would': 5,
#                           'to': 6,
#                           'he': 4,
#                           'agriculture': 72,
#                           'market': 7,
#                           'corn': 12,
#                           'will': 2,
#                           'feedgrain': 1,
#                           'which': 2,
#                           'limit': 1,
#                           'based': 2,
#                           'currency': 13,
#                           'sanctions': 3,
#                           'official': 3,
#                           'not': 3,
#                           'hopes': 2,
#                           'investors': 1,
#                           'dollar': 24,
#                           'unit': 3,
#                           'where': 6,
#                           'charges': 1,
#                           'decision': 1,
#                           'chip': 2,
#                           'concern': 1,
#                           'complaint': 1,
#                           'banking': 4,
#                           'treasury': 10,
#                           'petrochemical': 2,
#                           'chemical': 3,
#                           'economy': 12,
#                           'dlr': 9,
#                           'textile': 6,
#                           'investor': 1,
#                           'defense': 4,
#                           'government': 11,
#                           'no': 2,
#                           'a': 6,
#                           'parent': 1,
#                           'acquisition': 1,
#                           'tariffs': 4,
#                           'semiconductor': 3,
#                           'firms': 4,
#                           'purchase': 1,
#                           'medical': 2,
#                           'subsidiary': 6,
#                           'loan': 1,
#                           'lawmakers': 2,
#                           'dairy': 1,
#                           'interest': 8,
#                           'engineering': 1,
#                           'reserves': 1,
#                           'producers': 3,
#                           'meat': 9,
#                           'broilers': 1,
#                           'wheat': 8,
#                           'ports': 2,
#                           'prices': 1,
#                           'economic': 3,
#                           'probably': 1,
#                           'over': 2,
#                           'steel': 2,
#                           'have': 1,
#                           'senate': 5,
#                           'oil': 11,
#                           'consumption': 1,
#                           'current': 3,
#                           'imports': 2,
#                           'at': 2,
#                           'that': 1,
#                           'output': 1,
#                           'february': 4,
#                           'aegon': 1,
#                           'insurer': 1,
#                           'thus': 1,
#                           'first': 2,
#                           'funds': 2,
#                           'energy': 4,
#                           'gulf': 4,
#                           'commitment': 2,
#                           'company': 4,
#                           'buying': 1,
#                           'lead': 2,
#                           'courier': 2,
#                           'traders': 2,
#                           'congress': 3,
#                           'remained': 1,
#                           'tobacco': 1,
#                           'italy': 1,
#                           'march': 1,
#                           'retailers': 1,
#                           'soyoil': 1,
#                           'sugar': 2,
#                           'cts': 2,
#                           'outlook': 1,
#                           'ending': 2,
#                           'orange': 3,
#                           'supply': 4,
#                           'citrus': 1,
#                           'ussr': 3,
#                           'e': 1,
#                           'exporters': 2,
#                           'bankruptcy': 4,
#                           'may': 1,
#                           'depended': 1,
#                           'than': 1,
#                           'dependency': 1,
#                           'hatching': 1,
#                           'protein': 1,
#                           'weekly': 1,
#                           'soybean': 1,
#                           'x': 1,
#                           'quality': 1,
#                           'producing': 1,
#                           'spot': 1,
#                           'm': 4,
#                           'discount': 3,
#                           'bank': 4,
#                           'money': 3,
#                           'crude': 2,
#                           'relected': 1,
#                           'west': 2,
#                           'federal': 3,
#                           'commodities': 1,
#                           'markets': 1,
#                           'financial': 2,
#                           'reflected': 1,
#                           'budget': 4,
#                           'is': 3,
#                           'hurting': 1,
#                           'calls': 3,
#                           'machinery': 2,
#                           'green': 1,
#                           'roastings': 1,
#                           'european': 1,
#                           'u': 1,
#                           'bond': 1,
#                           'richards': 1,
#                           'companies': 2,
#                           'rate': 1,
#                           'monetary': 4,
#                           'industry': 3,
#                           'mln': 1,
#                           'feeder': 2,
#                           'bancorp': 5,
#                           'employees': 1,
#                           'trust': 6,
#                           'by': 2,
#                           'underwriters': 1,
#                           'revenues': 1,
#                           'it': 1,
#                           'on': 5,
#                           'sets': 1,
#                           'sprint': 1,
#                           'gas': 1,
#                           'competitors': 1,
#                           'plants': 3,
#                           'cattle': 2,
#                           'banks': 3,
#                           'inflation': 1,
#                           'east': 1,
#                           'rice': 2,
#                           'agricultural': 3,
#                           'agency': 1,
#                           'international': 1,
#                           'customs': 1,
#                           'bankrupcty': 1,
#                           'supreme': 1,
#                           'bid': 1,
#                           'believed': 1,
#                           'bill': 1,
#                           'soybeans': 5,
#                           'commerce': 4,
#                           'urges': 2,
#                           'they': 2,
#                           'rose': 3,
#                           'the': 2,
#                           'proposal': 1,
#                           'foodgrains': 1,
#                           'reprisals': 1,
#                           'goods': 3,
#                           'china': 1,
#                           'rules': 1,
#                           'support': 1,
#                           'retaliation': 1,
#                           'central': 1,
#                           'business': 1,
#                           'trading': 2,
#                           'arm': 1,
#                           'gnp': 1,
#                           'south': 2,
#                           'had': 2,
#                           'study': 1,
#                           'consumer': 3,
#                           'industrial': 1,
#                           'industries': 1,
#                           'manufacturing': 1,
#                           'district': 6,
#                           'rig': 1,
#                           'drilling': 1,
#                           'countervailing': 1,
#                           'or': 1,
#                           'zimmerman': 1,
#                           'forest': 1,
#                           'system': 1,
#                           'in': 2,
#                           'lumbermen': 1,
#                           'lumber': 1,
#                           'justice': 1,
#                           'publishing': 1,
#                           'video': 4,
#                           'allies': 2,
#                           'frigate': 3,
#                           'thrift': 3,
#                           'unprepared': 1,
#                           'participation': 1,
#                           'military': 4,
#                           'action': 1,
#                           'court': 4,
#                           'be': 1,
#                           'hart': 1,
#                           'did': 1,
#                           'firm': 2,
#                           'sectors': 1,
#                           'investment': 1,
#                           'should': 1,
#                           'gold': 2,
#                           'salmonellosis': 1,
#                           'house': 7,
#                           'allegis': 1,
#                           'weighs': 1,
#                           'domestic': 1,
#                           'ability': 1,
#                           'analysts': 1,
#                           'stocks': 2,
#                           'secretary': 2,
#                           'might': 1,
#                           'could': 2,
#                           'feed': 1,
#                           'flag': 3,
#                           'arms': 2,
#                           'warships': 3,
#                           'inc': 1,
#                           'holding': 1,
#                           'barley': 2,
#                           'flags': 2,
#                           'forces': 1,
#                           'wood': 1,
#                           'april': 1,
#                           'production': 1,
#                           'reserve': 3,
#                           'policy': 2,
#                           'upgraded': 1,
#                           'britain': 1,
#                           'owned': 1,
#                           'copper': 1,
#                           'warship': 1,
#                           'plan': 1,
#                           'during': 1,
#                           'beef': 4,
#                           'tenderloin': 1,
#                           'striploin': 1,
#                           'into': 1,
#                           'deficit': 2,
#                           'health': 1,
#                           'personal': 1,
#                           'league': 1,
#                           'benchmark': 1,
#                           'for': 2,
#                           'cent': 1,
#                           'superfund': 1,
#                           'was': 1,
#                           'chamber': 1,
#                           'technology': 1,
#                           'growth': 1,
#                           'farmers': 1,
#                           'canada': 1,
#                           'canadian': 1,
#                           'put': 1,
#                           'combining': 1,
#                           'housing': 1,
#                           'you': 1,
#                           'shaw': 1,
#                           'failed': 1,
#                           'groundnut': 1}),
#              ('s',
#               'japan'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'rift': 1, 's': 2, 'west': 2, 'trade': 1}),
#              ('japan',
#               'rift'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'mounting': 1}),
#              ('rift',
#               'mounting'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'trade': 1}),
#              ('mounting',
#               'trade'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'friction': 1, 'tension': 1}),
#              ('trade',
#               'friction'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'between': 3, 'with': 1, 'diplomacy': 1, 'and': 1}),
#              ('friction',
#               'between'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 3}),
#              ('between',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'u': 5,
#                           'start': 1,
#                           'two': 18,
#                           'employers': 1,
#                           'united': 4,
#                           'demands': 1,
#                           'countries': 1,
#                           'ec': 1,
#                           'dollar': 1,
#                           'white': 1,
#                           'prime': 3,
#                           'report': 2,
#                           'increased': 1,
#                           'secured': 1,
#                           'pork': 1,
#                           'omani': 1,
#                           'group': 1,
#                           'purchase': 1,
#                           'federal': 1,
#                           'first': 1,
#                           'heaviest': 1,
#                           'growth': 1}),
#              ('the',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'s': 413, 'k': 17, 'n': 1}),
#              ('s',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'japan': 6,
#                           'lead': 1,
#                           'atlas': 1,
#                           'new': 1,
#                           'japanese': 3,
#                           'rising': 1,
#                           'britain': 2,
#                           'europe': 2,
#                           'west': 3,
#                           'world': 1,
#                           'european': 1,
#                           'the': 2,
#                           'cain': 1,
#                           'canada': 2,
#                           'l': 1,
#                           'up': 1,
#                           'hong': 1,
#                           'u': 1,
#                           'its': 1,
#                           'w': 4,
#                           'other': 2,
#                           'malaysia': 1,
#                           'rupert': 1,
#                           'tight': 1,
#                           'on': 1,
#                           'canadian': 1,
#                           'raise': 1}),
#              ('and',
#               'japan'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'has': 1,
#                           'might': 1,
#                           'with': 2,
#                           's': 2,
#                           'harder': 1,
#                           'look': 1,
#                           'on': 3,
#                           'believe': 1,
#                           'became': 1,
#                           'which': 1,
#                           'meanwhile': 1,
#                           'rather': 1,
#                           'will': 2,
#                           'at': 1,
#                           'to': 2}),
#              ('japan',
#               'has'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'raised': 1,
#                           'been': 2,
#                           'the': 1,
#                           'little': 2,
#                           'violated': 1,
#                           'said': 3,
#                           'come': 1,
#                           'no': 3,
#                           'rejected': 1,
#                           'far': 1,
#                           'resulted': 1}),
#              ('has',
#               'raised'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'fears': 1,
#                           'its': 2,
#                           'concern': 1,
#                           'the': 1,
#                           'his': 1,
#                           'prices': 1}),
#              ('raised',
#               'fears'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'among': 1}),
#              ('fears',
#               'among'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'many': 1}),
#              ('among',
#               'many'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1}),
#              ('many',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'asia': 1, 'the': 3}),
#              ('of',
#               'asia'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'s': 1}),
#              ('asia',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'exporting': 1}),
#              ('s',
#               'exporting'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'nations': 1}),
#              ('exporting',
#               'nations'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'that': 1, 'to': 1}),
#              ('nations',
#               'that'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1, 'relative': 1, 'are': 1}),
#              ('that',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'row': 1,
#                           'exchange': 1,
#                           'withdrawal': 1,
#                           'underlying': 2,
#                           'two': 3,
#                           'situation': 4,
#                           'listings': 1,
#                           'issuing': 1,
#                           'process': 1,
#                           'transaction': 1,
#                           'dollar': 13,
#                           'correction': 1,
#                           'mark': 2,
#                           'u': 10,
#                           'chemical': 1,
#                           'cocoa': 1,
#                           'storage': 1,
#                           'parties': 1,
#                           'company': 11,
#                           'italian': 1,
#                           'danger': 1,
#                           'talks': 2,
#                           'first': 1,
#                           'move': 2,
#                           'market': 2,
#                           'negotiation': 1,
#                           'value': 1,
#                           'only': 2,
#                           'discount': 1,
#                           'bundesbank': 2,
#                           'commission': 1,
#                           'current': 4,
#                           'solidarity': 1,
#                           'markets': 4,
#                           'changes': 1,
#                           'key': 2,
#                           'average': 2,
#                           'last': 1,
#                           'ability': 1,
#                           'impact': 1,
#                           'total': 1,
#                           'german': 1,
#                           'substantial': 1,
#                           'reagan': 2,
#                           'bill': 1,
#                           'financial': 2,
#                           'finance': 1,
#                           'full': 1,
#                           'it': 1,
#                           'consumer': 1,
#                           'government': 8,
#                           'monthly': 1,
#                           'so': 1,
#                           'soviet': 2,
#                           'fire': 1,
#                           'securing': 1,
#                           'second': 2,
#                           'system': 2,
#                           'fund': 1,
#                           'industrial': 1,
#                           'fed': 19,
#                           'latest': 1,
#                           'yen': 2,
#                           'controlled': 1,
#                           'foreign': 1,
#                           'tariffs': 2,
#                           'group': 2,
#                           'much': 1,
#                           'worst': 1,
#                           'debtholders': 2,
#                           'ec': 4,
#                           'bankers': 1,
#                           'highest': 1,
#                           'grind': 1,
#                           'estimates': 1,
#                           'braking': 1,
#                           'trade': 2,
#                           'strengthening': 1,
#                           'positive': 1,
#                           'scope': 1,
#                           'americans': 1,
#                           'amended': 1,
#                           'mln': 1,
#                           'companies': 1,
#                           'issue': 1,
#                           'price': 3,
#                           'other': 1,
#                           'plants': 1,
#                           'chances': 1,
#                           'energy': 1,
#                           'epa': 1,
#                           'imports': 1,
#                           'removal': 2,
#                           'central': 2,
#                           'japanese': 2,
#                           'sale': 1,
#                           'federal': 3,
#                           'commerce': 1,
#                           'pct': 1,
#                           'health': 1,
#                           'main': 2,
#                           'trading': 2,
#                           'standard': 1,
#                           'bank': 2,
#                           'factor': 1,
#                           'philippines': 1,
#                           'pact': 2,
#                           'offer': 1,
#                           'renegotiations': 1,
#                           'dutch': 1,
#                           'merger': 1,
#                           'deal': 1,
#                           'elimination': 1,
#                           'allies': 1,
#                           'management': 1,
#                           'pipeline': 3,
#                           'water': 1,
#                           'proposed': 1,
#                           'shareholding': 1,
#                           'independent': 1,
#                           'net': 1,
#                           'west': 3,
#                           'economy': 6,
#                           'petroleum': 1,
#                           'peso': 1,
#                           'united': 1,
#                           'area': 1,
#                           'vessels': 1,
#                           'measure': 1,
#                           'rising': 1,
#                           'remaining': 2,
#                           'downtrend': 1,
#                           'louvre': 1,
#                           'six': 1,
#                           'white': 1,
#                           'intent': 1,
#                           'budget': 2,
#                           'acp': 1,
#                           'british': 1,
#                           'timing': 1,
#                           'proposal': 1,
#                           'the': 1,
#                           'telegraph': 1,
#                           'country': 1,
#                           'status': 1,
#                           'shares': 1,
#                           'returns': 1,
#                           'share': 1,
#                           'merged': 1,
#                           'crop': 1,
#                           'document': 1,
#                           'ruling': 1,
#                           'acquisition': 1,
#                           'sacrifices': 1,
#                           'provisions': 1,
#                           'auction': 1,
#                           'storm': 1,
#                           'purchasing': 1,
#                           'metal': 2,
#                           'medium': 1,
#                           'gnp': 1,
#                           'ministry': 1,
#                           'dlrs': 1}),
#              ('the',
#               'row'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'could': 1}),
#              ('row',
#               'could'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'inflict': 1}),
#              ('could',
#               'inflict'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'far': 1}),
#              ('inflict',
#               'far'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'reaching': 1}),
#              ('far',
#               'reaching'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'economic': 1}),
#              ('reaching',
#               'economic'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'damage': 1}),
#              ('economic',
#               'damage'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'businessmen': 1}),
#              ('damage',
#               'businessmen'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1}),
#              ('businessmen',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'officials': 2}),
#              ('and',
#               'officials'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'said': 1,
#                           'are': 1,
#                           'still': 2,
#                           'have': 1,
#                           'told': 1}),
#              ('they',
#               'told'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'reuter': 1, 'reporters': 1, 'reuters': 1}),
#              ('told',
#               'reuter'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'correspondents': 1}),
#              ('reuter',
#               'correspondents'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1, 'included': 1, 'returning': 1}),
#              ('correspondents',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'asian': 1}),
#              ('in',
#               'asian'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'capitals': 1}),
#              ('asian',
#               'capitals'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'a': 1}),
#              ('capitals',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'u': 1}),
#              ('a',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'s': 22}),
#              ('s',
#               'move'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'against': 1,
#                           'to': 3,
#                           'reverses': 1,
#                           'follows': 1,
#                           'has': 1,
#                           'is': 1}),
#              ('move',
#               'against'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'japan': 1}),
#              ('against',
#               'japan'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'might': 2,
#                           'because': 1,
#                           'to': 4,
#                           'were': 1,
#                           'but': 1,
#                           'last': 1}),
#              ('japan',
#               'might'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'boost': 1,
#                           'also': 1,
#                           'allow': 1,
#                           'challenge': 1,
#                           'take': 1}),
#              ('might',
#               'boost'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'protectionist': 1, 'its': 1}),
#              ('boost',
#               'protectionist'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'sentiment': 1}),
#              ('protectionist',
#               'sentiment'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1}),
#              ('sentiment',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1}),
#              ('in',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'u': 54,
#                           'long': 5,
#                           'short': 6,
#                           'first': 93,
#                           'year': 31,
#                           'value': 12,
#                           'fiscal': 3,
#                           'ports': 3,
#                           'exchange': 2,
#                           'northern': 3,
#                           'tokyo': 1,
#                           'bank': 4,
#                           'near': 20,
#                           'context': 3,
#                           'banking': 1,
#                           'market': 13,
#                           'central': 8,
#                           'second': 16,
#                           'philippines': 2,
#                           'industrial': 4,
#                           'money': 9,
#                           'surplus': 2,
#                           'study': 1,
#                           'west': 4,
#                           'last': 9,
#                           'economy': 9,
#                           'number': 5,
#                           'capital': 3,
#                           'dollar': 10,
#                           'trade': 4,
#                           'past': 33,
#                           'best': 6,
#                           'direction': 2,
#                           'australian': 1,
#                           'booming': 1,
#                           'gold': 2,
#                           'same': 30,
#                           'united': 22,
#                           'tourism': 1,
#                           'form': 14,
#                           'recession': 1,
#                           'budget': 7,
#                           'morning': 3,
#                           'system': 1,
#                           'philippine': 1,
#                           'neighbourhood': 1,
#                           'mackay': 1,
#                           'area': 10,
#                           'company': 26,
#                           'rotterdam': 1,
#                           'sector': 4,
#                           'port': 2,
#                           'financing': 1,
#                           'ground': 1,
#                           'netherlands': 6,
#                           'producer': 1,
#                           'retail': 1,
#                           'consumer': 1,
#                           'week': 35,
#                           'middle': 2,
#                           'case': 5,
#                           'month': 7,
#                           'building': 1,
#                           'adjusted': 1,
#                           'government': 3,
#                           'fortunes': 1,
#                           'early': 4,
#                           'niche': 1,
#                           'chemical': 1,
#                           'quarter': 10,
#                           'weeks': 2,
#                           'fourth': 17,
#                           'trading': 1,
#                           'centre': 1,
#                           'annual': 2,
#                           'telecommunications': 1,
#                           'japanese': 3,
#                           'aegean': 2,
#                           'new': 11,
#                           'key': 1,
#                           'industry': 3,
#                           'future': 7,
#                           'gulf': 30,
#                           'entire': 1,
#                           'world': 4,
#                           'meat': 1,
#                           'event': 5,
#                           'course': 6,
#                           'talks': 1,
#                           'ibm': 1,
#                           'ball': 1,
#                           'face': 3,
#                           'domestic': 2,
#                           'nation': 2,
#                           'january': 2,
#                           'strategic': 1,
#                           'filing': 2,
#                           'sec': 1,
#                           'four': 2,
#                           'period': 3,
#                           'cost': 5,
#                           'estimated': 1,
#                           'santos': 1,
#                           'planned': 1,
#                           's': 4,
#                           'financial': 3,
#                           'postal': 1,
#                           'meeting': 2,
#                           'louvre': 6,
#                           'far': 3,
#                           'soviet': 2,
#                           'british': 2,
#                           'fixed': 1,
#                           'spot': 4,
#                           'country': 6,
#                           'transaction': 3,
#                           'discussions': 3,
#                           'us': 1,
#                           'next': 13,
#                           'coming': 1,
#                           'repurchase': 1,
#                           'hague': 3,
#                           'statement': 5,
#                           'days': 1,
#                           'rhineland': 1,
#                           'san': 1,
#                           'sale': 2,
#                           'prior': 7,
#                           'pound': 1,
#                           'timecharter': 1,
#                           'hours': 2,
#                           'meantime': 3,
#                           'areas': 2,
#                           'february': 4,
#                           'light': 3,
#                           'reafffirmation': 1,
#                           'yen': 1,
#                           'imf': 2,
#                           'developed': 3,
#                           'initial': 1,
#                           'agriculture': 1,
#                           'alleged': 1,
#                           'open': 5,
#                           'six': 1,
#                           'communique': 1,
#                           'easier': 1,
#                           'european': 6,
#                           'chicago': 2,
#                           'group': 1,
#                           'center': 1,
#                           'cocoa': 1,
#                           'calabria': 1,
#                           'region': 5,
#                           'brazilian': 1,
#                           'housing': 1,
#                           'east': 1,
#                           'economically': 1,
#                           'beginning': 1,
#                           'finance': 1,
#                           'goods': 1,
#                           'house': 5,
#                           'sugar': 1,
#                           'session': 1,
#                           'management': 3,
#                           'stockpile': 2,
#                           'automotive': 1,
#                           'canadian': 3,
#                           'season': 3,
#                           'crop': 1,
#                           'current': 6,
#                           'mine': 2,
#                           'previous': 4,
#                           'most': 1,
#                           'corresponding': 6,
#                           'operating': 1,
#                           'energy': 1,
#                           'fed': 2,
#                           'latest': 5,
#                           'march': 2,
#                           'over': 1,
#                           'third': 7,
#                           'mediterranean': 1,
#                           'global': 1,
#                           'right': 1,
#                           'broussard': 1,
#                           'metal': 1,
#                           'grain': 1,
#                           'two': 7,
#                           'final': 1,
#                           'massive': 1,
#                           'discount': 3,
#                           'bond': 1,
#                           'g': 1,
#                           'state': 4,
#                           'name': 1,
#                           'kingdom': 2,
#                           'crisis': 1,
#                           'major': 2,
#                           'asset': 1,
#                           'southern': 2,
#                           'report': 3,
#                           'city': 1,
#                           'electronics': 1,
#                           'forest': 1,
#                           'papua': 1,
#                           'adjacent': 1,
#                           'institutes': 1,
#                           'winter': 1,
#                           'private': 3,
#                           'manufactured': 1,
#                           'tertiary': 1,
#                           'manufacturing': 2,
#                           'low': 2,
#                           'merger': 2,
#                           'th': 1,
#                           'offer': 3,
#                           'field': 6,
#                           'three': 4,
#                           'index': 1,
#                           'tender': 3,
#                           'newspaper': 2,
#                           'existing': 1,
#                           'pipeline': 1,
#                           'products': 1,
#                           'stock': 2,
#                           'property': 1,
#                           'preceeding': 1,
#                           'greek': 1,
#                           'disposal': 1,
#                           'this': 1,
#                           'discrepancy': 1,
#                           'summer': 1,
#                           'pending': 1,
#                           'amended': 1,
#                           'paris': 2,
#                           'medical': 1,
#                           'nelson': 1,
#                           'ballpark': 1,
#                           'nine': 2,
#                           'little': 1,
#                           'hands': 1,
#                           'combined': 1,
#                           'external': 1,
#                           'note': 1,
#                           'acre': 1,
#                           'venture': 1,
#                           'court': 1,
#                           'version': 1,
#                           'cincinnati': 1,
#                           'acquisition': 1,
#                           'province': 1,
#                           'hurghada': 1,
#                           'shipping': 2,
#                           'december': 2,
#                           'months': 2,
#                           'merged': 1,
#                           'paper': 1,
#                           'import': 1,
#                           'national': 1,
#                           'deficit': 1,
#                           'expansion': 1,
#                           'rural': 1,
#                           'countries': 1,
#                           'western': 2,
#                           'hope': 1,
#                           'dumping': 1,
#                           'bidding': 1,
#                           'arctic': 1,
#                           'wake': 3,
#                           'interests': 2,
#                           'general': 1,
#                           'washington': 1,
#                           'foreign': 3,
#                           'fuel': 1,
#                           'magnitude': 1,
#                           'transfer': 1,
#                           'overall': 1,
#                           'dinar': 1,
#                           'sun': 1,
#                           'doldrums': 1,
#                           'defense': 1,
#                           'copperbelt': 3,
#                           'politically': 1,
#                           'bombay': 1,
#                           'contract': 1,
#                           'interior': 1,
#                           'leveraged': 1,
#                           'opinion': 1,
#                           'public': 1,
#                           'harcourt': 1,
#                           'international': 3,
#                           'luckey': 1,
#                           'unit': 1,
#                           'painewebber': 1,
#                           'program': 1,
#                           'heidrun': 1,
#                           'interest': 1,
#                           'longer': 1,
#                           'deal': 1,
#                           'process': 4,
#                           'nearby': 4,
#                           'back': 1,
#                           'south': 4,
#                           'price': 1,
#                           'applications': 1,
#                           'computer': 1,
#                           'mideast': 4,
#                           'game': 1,
#                           'manufacture': 1,
#                           'red': 1,
#                           'river': 1,
#                           'test': 1,
#                           'tentative': 1,
#                           'southwest': 2,
#                           'fierce': 1,
#                           'denim': 1,
#                           'recapitalized': 1,
#                           'absence': 1,
#                           'sense': 1,
#                           'total': 1,
#                           'ortheast': 1,
#                           'khur': 1,
#                           'waterway': 1,
#                           'lpg': 1,
#                           'thermoplastic': 1,
#                           'continuing': 1,
#                           'sectors': 1,
#                           'reserves': 1,
#                           'political': 1,
#                           'jaffna': 1,
#                           'driving': 1,
#                           'virginia': 1,
#                           'balance': 2,
#                           'machine': 1,
#                           'late': 2,
#                           'full': 1,
#                           'class': 1,
#                           'mid': 1,
#                           'volcker': 1,
#                           'toledo': 1,
#                           'lome': 1,
#                           'eastern': 2,
#                           'anaheim': 1,
#                           'icco': 1,
#                           'joint': 1,
#                           'bill': 1,
#                           'acreage': 2,
#                           'use': 1,
#                           'textile': 1,
#                           'subsequent': 1,
#                           'northwest': 1,
#                           'persian': 1,
#                           'oil': 2,
#                           'so': 1,
#                           'good': 1,
#                           'north': 1,
#                           'quota': 1,
#                           'senate': 1,
#                           'euromarket': 1,
#                           'ec': 2,
#                           'pct': 1,
#                           'autumn': 1,
#                           'may': 1,
#                           'cane': 1,
#                           'lower': 1,
#                           'supply': 1,
#                           'suit': 1,
#                           'severance': 1,
#                           'mortgage': 1,
#                           'agricultural': 2,
#                           'medium': 1,
#                           'contribution': 1,
#                           'seasonally': 1,
#                           'oils': 2,
#                           'community': 1,
#                           'product': 1,
#                           'properties': 1,
#                           'peninsula': 1,
#                           'zccm': 1,
#                           'london': 1,
#                           'development': 1,
#                           'tribal': 1,
#                           'growth': 1,
#                           'five': 1,
#                           'research': 1,
#                           'upside': 1,
#                           'spokesman': 1,
#                           'book': 1,
#                           'french': 1,
#                           'different': 1,
#                           'other': 1,
#                           'unemployment': 1,
#                           'broader': 1,
#                           'albras': 1,
#                           'rand': 1,
#                           'neutral': 1,
#                           'wrong': 1}),
#              ('and',
#               'lead'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'to': 4, 'a': 1}),
#              ('lead',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'curbs': 1,
#                           'pressure': 1,
#                           'trade': 1,
#                           'britain': 1,
#                           'the': 2,
#                           'still': 1,
#                           'a': 5,
#                           'an': 1,
#                           'recession': 1,
#                           'lower': 1,
#                           'new': 1,
#                           'renewed': 2,
#                           'mergers': 1,
#                           'their': 1,
#                           'wastage': 1,
#                           'ec': 1,
#                           'improving': 1,
#                           'foreign': 1,
#                           'higher': 1,
#                           'war': 1,
#                           'british': 1,
#                           'job': 1,
#                           'upward': 1,
#                           'attractive': 1}),
#              ('to',
#               'curbs'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'on': 1}),
#              ('curbs',
#               'on'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'american': 1,
#                           'japanese': 1,
#                           'products': 1,
#                           'capital': 1,
#                           'government': 1,
#                           'growth': 1}),
#              ('on',
#               'american'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'imports': 1, 'products': 1, 'servicemen': 1}),
#              ('american',
# ...
#                           'restructuring': 1,
#                           'planned': 1,
#                           'drought': 1,
#                           'a': 10,
#                           'particularly': 1,
#                           'setbacks': 1,
#                           'an': 2,
#                           'including': 1,
#                           'non': 1,
#                           'changes': 1,
#                           'competition': 1,
#                           'more': 1,
#                           'their': 1,
#                           'production': 1,
#                           'gencorp': 1,
#                           'recent': 1,
#                           'unprecedented': 1,
#                           'our': 1,
#                           'rising': 4,
#                           'its': 5,
#                           'uncertainty': 1,
#                           'foreign': 1,
#                           'distortions': 1,
#                           'extreme': 1,
#                           'low': 2,
#                           'inadequate': 1,
#                           'flood': 1,
#                           'flooding': 1,
#                           'severe': 1,
#                           'any': 1,
#                           'greater': 1,
#                           'japan': 1,
#                           'inefficiencies': 2,
#                           'over': 2,
#                           'opposition': 1,
#                           'congressional': 1,
#                           'exchange': 1,
#                           'insufficient': 1,
#                           'several': 1}),
#              ('of',
#               'better'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'european': 1}),
#              ('better',
#               'european'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'demand': 1}),
#              ('european',
#               'demand'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1}),
#              ('demand',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'a': 1,
#                           'in': 1,
#                           'less': 1,
#                           'welcomed': 1,
#                           'production': 2,
#                           'lead': 1,
#                           'because': 1,
#                           'will': 2,
#                           'price': 1,
#                           'low': 1,
#                           'tight': 1,
#                           'higher': 1,
#                           'tougher': 1,
#                           'increase': 1}),
#              ('a',
#               'fall'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 4, 'of': 5, 'from': 1}),
#              ('fall',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'malaysian': 1,
#                           'the': 9,
#                           'sales': 1,
#                           'march': 1,
#                           'key': 1,
#                           'imports': 1,
#                           'oil': 3,
#                           'but': 1,
#                           'latest': 1,
#                           'week': 1,
#                           'major': 1,
#                           'note': 1,
#                           'january': 2,
#                           'exports': 1,
#                           'february': 1,
#                           'input': 1,
#                           'industrial': 2,
#                           'a': 1,
#                           'may': 3,
#                           'unemployment': 1,
#                           'canadian': 1}),
#              ('in',
#               'malaysian'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'output': 1, 'and': 1}),
#              ('malaysian',
#               'output'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'hasrul': 1}),
#              ('output',
#               'hasrul'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'harahap': 1}),
#              ('hasrul',
#               'harahap'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'junior': 1}),
#              ('harahap',
#               'junior'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'minister': 1}),
#              ('junior',
#               'minister'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'for': 1}),
#              ('minister',
#               'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'tree': 1, 'foreign': 1}),
#              ('for',
#               'tree'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'crops': 1}),
#              ('tree',
#               'crops'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'told': 1}),
#              ('crops',
#               'told'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'indonesian': 1}),
#              ('told',
#               'indonesian'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'reporters': 1}),
#              ('prices',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'malaysian': 1,
#                           'pct': 1,
#                           'grain': 1,
#                           'corn': 1,
#                           'home': 1,
#                           'cement': 1,
#                           'the': 1,
#                           'petrol': 4,
#                           'cents': 1,
#                           'gm': 1,
#                           'coconut': 1,
#                           'its': 1,
#                           'aluminum': 4,
#                           'up': 1,
#                           'such': 1,
#                           'to': 1,
#                           'tungsten': 1,
#                           'high': 1,
#                           'sweet': 1,
#                           'around': 1}),
#              ('of',
#               'malaysian'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1, 'refined': 1}),
#              ('malaysian',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'sumatran': 1, 'japanese': 1, 'indonesian': 1}),
#              ('and',
#               'sumatran'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'cpo': 1}),
#              ('sumatran',
#               'cpo'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'are': 1}),
#              ('cpo',
#               'are'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'now': 1}),
#              ('are',
#               'now'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'around': 1,
#                           'within': 2,
#                           'near': 1,
#                           'paying': 1,
#                           'being': 1}),
#              ('now',
#               'around'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'dlrs': 1}),
#              ('around',
#               'dlrs'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'a': 13, 'per': 1}),
#              ('tonne',
#               'cif'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'for': 1}),
#              ('cif',
#               'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'delivery': 1}),
#              ('for',
#               'delivery'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 9,
#                           'between': 1,
#                           'to': 3,
#                           'may': 3,
#                           'during': 5,
#                           'as': 1,
#                           'at': 1,
#                           'august': 1,
#                           'before': 1,
#                           'of': 1}),
#              ('delivery',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'rotterdam': 1,
#                           'the': 5,
#                           'including': 1,
#                           'gold': 1,
#                           'two': 1,
#                           'late': 1}),
#              ('in',
#               'rotterdam'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'traders': 1, 'the': 1}),
#              ('rotterdam',
#               'traders'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'said': 1}),
#              ('harahap',
#               'said'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'indonesia': 1, 'it': 1}),
#              ('said',
#               'indonesia'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'would': 1, 'was': 1, 's': 2, 'had': 1}),
#              ('indonesia',
#               'would'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'maintain': 1}),
#              ('would',
#               'maintain'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'its': 1}),
#              ('maintain',
#               'its'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'exports': 1,
#                           'latest': 1,
#                           'dialogue': 1,
#                           'current': 2,
#                           'pct': 1}),
#              ('its',
#               'exports'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'despite': 1}),
#              ('exports',
#               'despite'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'making': 1}),
#              ('despite',
#               'making'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'recent': 1}),
#              ('making',
#               'recent'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'palm': 1}),
#              ('recent',
#               'palm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'oil': 1}),
#              ('oil',
#               'purchases'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'from': 1}),
#              ('purchases',
#               'from'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'malaysia': 1}),
#              ('from',
#               'malaysia'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'so': 1}),
#              ('malaysia',
#               'so'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'that': 1}),
#              ('so',
#               'that'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'it': 1,
#                           'we': 2,
#                           'certain': 1,
#                           'more': 1,
#                           'abe': 2,
#                           'in': 2}),
#              ('that',
#               'it'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'could': 1,
#                           's': 2,
#                           'had': 6,
#                           'plans': 1,
#                           'has': 10,
#                           'was': 10,
#                           'is': 9,
#                           'wants': 1,
#                           'may': 2,
#                           'should': 1,
#                           'proposed': 1,
#                           'continue': 1,
#                           'did': 1,
#                           'owns': 1,
#                           'made': 2,
#                           'would': 13,
#                           'wanted': 1,
#                           'already': 1,
#                           'will': 3,
#                           'does': 2,
#                           'turned': 1,
#                           'the': 1,
#                           'and': 1,
#                           'intends': 1,
#                           'regards': 1,
#                           'announced': 1,
#                           'enjoyed': 1,
#                           'awarded': 1}),
#              ('it',
#               'could'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'possibly': 1,
#                           'open': 1,
#                           'be': 2,
#                           'put': 1,
#                           'sustain': 1,
#                           'take': 2,
#                           'realize': 1,
#                           'also': 2,
#                           'still': 1,
#                           'drop': 1,
#                           'lead': 1,
#                           'not': 1}),
#              ('could',
#               'possibly'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'increase': 1}),
#              ('possibly',
#               'increase'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'its': 1}),
#              ('increase',
#               'its'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'international': 1,
#                           'holding': 1,
#                           'annual': 1,
#                           'sales': 1,
#                           'wheat': 1,
#                           'dlr': 1,
#                           'stake': 1,
#                           'provision': 1,
#                           'ability': 1}),
#              ('its',
#               'international'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'market': 1, 'oil': 1, 'value': 1, 'business': 1}),
#              ('international',
#               'market'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'share': 1, 'because': 1}),
#              ('indonesia',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'world': 1}),
#              ('s',
#               'second'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'largest': 4, 'hand': 1, 'quarter': 1}),
#              ('second',
#               'largest'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'producer': 2,
#                           'employer': 2,
#                           'gold': 1,
#                           'consumers': 1}),
#              ('largest',
#               'producer'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 2, 'in': 1}),
#              ('producer',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'palm': 1,
#                           'natural': 1,
#                           'telephone': 1,
#                           'the': 2,
#                           'pasta': 1,
#                           'canned': 1,
#                           'peanuts': 1}),
#              ('of',
#               'palm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'oil': 3, 'olein': 1}),
#              ...})

# %%
#from nltk.util import ngrams

# Unigrams
#df['unigrams'] = df['tokenized_text'].apply(lambda x: list(ngrams(x, 1)))

# Bigrams
#df['bigrams'] = df['tokenized_text'].apply(lambda x: list(ngrams(x, 2)))

# Trigrams
#df['trigrams'] = df['tokenized_text'].apply(lambda x: list(ngrams(x, 3)))

# %%
#from collections import defaultdict

# Count occurrences of trigrams
#trigram_counts = defaultdict(lambda: defaultdict(lambda: 0))
#for sentence in df['trigrams']:
    #for trigram in sentence:
       # trigram_counts[trigram[:2]][trigram[2]] += 1

# %%
# predict the next word
dict(model["asian", "exporters"])
# Out:
# {'fear': 1}

# %%
#prob model

# %%
# creating the unigram list
unigram_dict = {}
for i in tqdm(range(df.shape[0])):
    # add word-count pair to the dictionary
    for word in df['unigram'][i]:   
        # check if the word is already in dictionary 
        if word[0] in unigram_dict:
            # increment count of word by 1 
            unigram_dict[word[0]] = unigram_dict[word[0]] + 1
        else:
            # add the word to dictionary with count 1 
            unigram_dict[word[0]] = 1
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 10000/10000 [00:00<00:00, 31876.60it/s]

# %%
# unigram list
unigram_dict
# Out:
# {'asian': 13,
#  'exporters': 52,
#  'fear': 8,
#  'damage': 29,
#  'from': 1369,
#  'u': 1117,
#  's': 2864,
#  'japan': 441,
#  'rift': 1,
#  'mounting': 5,
#  'trade': 549,
#  'friction': 8,
#  'between': 191,
#  'the': 12496,
#  'and': 4599,
#  'has': 974,
#  'raised': 70,
#  'fears': 13,
#  'among': 44,
#  'many': 54,
#  'of': 6671,
#  'asia': 14,
#  'exporting': 12,
#  'nations': 71,
#  'that': 1376,
#  'row': 3,
#  'could': 291,
#  'inflict': 1,
#  'far': 55,
#  'reaching': 7,
#  'economic': 244,
#  'businessmen': 15,
#  'officials': 190,
#  'said': 4649,
#  'they': 518,
#  'told': 237,
#  'reuter': 27,
#  'correspondents': 3,
#  'in': 5070,
#  'capitals': 3,
#  'a': 4412,
#  'move': 101,
#  'against': 270,
#  'might': 59,
#  'boost': 45,
#  'protectionist': 22,
#  'sentiment': 10,
#  'lead': 96,
#  'to': 6337,
#  'curbs': 12,
#  'on': 1643,
#  'american': 126,
#  'imports': 242,
#  'their': 230,
#  'products': 200,
#  'but': 650,
#  'some': 278,
#  'while': 164,
#  'conflict': 3,
#  'would': 926,
#  'hurt': 11,
#  'them': 58,
#  'long': 119,
#  'run': 21,
#  'short': 87,
#  'term': 120,
#  'tokyo': 75,
#  'loss': 607,
#  'be': 1165,
#  'gain': 101,
#  'it': 1970,
#  'will': 984,
#  'impose': 20,
#  'mln': 3064,
#  'dlrs': 2140,
#  'tariffs': 82,
#  'japanese': 192,
#  'electronics': 25,
#  'goods': 69,
#  'april': 477,
#  'retaliation': 20,
#  'for': 2592,
#  'alleged': 11,
#  'failure': 23,
#  'stick': 1,
#  'pact': 59,
#  'not': 838,
#  'sell': 139,
#  'semiconductors': 9,
#  'world': 166,
#  'markets': 182,
#  'at': 1311,
#  'below': 66,
#  'cost': 86,
#  'unofficial': 1,
#  'estimates': 62,
#  'put': 59,
#  'impact': 52,
#  'billion': 1112,
#  'spokesmen': 3,
#  'major': 206,
#  'firms': 57,
#  'virtually': 14,
#  'halt': 10,
#  'exports': 294,
#  'hit': 37,
#  'by': 1375,
#  'new': 474,
#  'taxes': 29,
#  'we': 258,
#  'wouldn': 6,
#  't': 115,
#  'able': 31,
#  'do': 90,
#  'business': 171,
#  'spokesman': 166,
#  'leading': 49,
#  'firm': 114,
#  'matsushita': 1,
#  'electric': 35,
#  'industrial': 120,
#  'co': 370,
#  'ltd': 273,
#  'lt': 1498,
#  'mc': 1,
#  'if': 282,
#  'remain': 55,
#  'place': 31,
#  'any': 142,
#  'length': 1,
#  'time': 145,
#  'beyond': 12,
#  'few': 42,
#  'months': 164,
#  'mean': 11,
#  'complete': 22,
#  'erosion': 2,
#  'subject': 72,
#  'tom': 4,
#  'murtha': 1,
#  'stock': 394,
#  'analyst': 60,
#  'office': 44,
#  'broker': 21,
#  'james': 33,
#  'capel': 2,
#  'taiwan': 62,
#  'are': 625,
#  'also': 442,
#  'worried': 15,
#  'aware': 7,
#  'seriousness': 3,
#  'threat': 11,
#  'because': 214,
#  'serves': 3,
#  'as': 884,
#  'warning': 5,
#  'us': 41,
#  'senior': 40,
#  'taiwanese': 4,
#  'official': 174,
#  'who': 98,
#  'asked': 74,
#  'named': 38,
#  'had': 512,
#  'surplus': 155,
#  'last': 654,
#  'year': 1212,
#  'pct': 1811,
#  'with': 1127,
#  'helped': 21,
#  'swell': 2,
#  'foreign': 253,
#  'exchange': 279,
#  'reserves': 153,
#  'largest': 79,
#  'must': 46,
#  'quickly': 18,
#  'open': 98,
#  'our': 101,
#  'remove': 9,
#  'barriers': 12,
#  'cut': 206,
#  'import': 67,
#  'allow': 40,
#  'want': 43,
#  'defuse': 2,
#  'problems': 55,
#  'possible': 72,
#  'paul': 21,
#  'sheen': 1,
#  'chairman': 145,
#  'textile': 32,
#  'safe': 3,
#  'group': 342,
#  'south': 135,
#  'korea': 49,
#  'promotion': 5,
#  'association': 53,
#  'dispute': 24,
#  'pressure': 57,
#  'whose': 21,
#  'chief': 51,
#  'similar': 36,
#  'those': 75,
#  'up': 386,
#  'malaysia': 21,
#  'officers': 17,
#  'tough': 23,
#  'hard': 37,
#  'producers': 72,
#  'third': 67,
#  'countries': 142,
#  'expand': 25,
#  'sales': 371,
#  'hong': 26,
#  'kong': 26,
#  'where': 60,
#  'newspapers': 5,
#  'have': 542,
#  'been': 396,
#  'selling': 42,
#  'manufacturers': 15,
#  'share': 516,
#  'view': 40,
#  'other': 331,
#  'such': 100,
#  'commercial': 41,
#  'advantage': 8,
#  'outweighed': 2,
#  'further': 172,
#  'block': 19,
#  'is': 1420,
#  'very': 72,
#  'lawrence': 2,
#  'mills': 17,
#  'director': 41,
#  'general': 86,
#  'federation': 20,
#  'industry': 200,
#  'whole': 20,
#  'purpose': 9,
#  'prevent': 30,
#  'one': 508,
#  'day': 132,
#  'extended': 19,
#  'sources': 161,
#  'much': 92,
#  'more': 354,
#  'serious': 13,
#  'disadvantage': 2,
#  'action': 82,
#  'restraining': 2,
#  'he': 971,
#  'was': 1127,
#  'biggest': 24,
#  'export': 152,
#  'market': 498,
#  'accounting': 24,
#  'over': 236,
#  'domestically': 5,
#  'produced': 45,
#  'australian': 56,
#  'government': 304,
#  'awaiting': 9,
#  'outcome': 12,
#  'talks': 112,
#  'interest': 252,
#  'concern': 39,
#  'minister': 122,
#  'john': 24,
#  'button': 2,
#  'canberra': 1,
#  'friday': 44,
#  'this': 642,
#  'kind': 13,
#  'deterioration': 6,
#  'relations': 13,
#  'two': 444,
#  'which': 643,
#  'trading': 141,
#  'partners': 57,
#  'ours': 2,
#  'matter': 16,
#  'australia': 55,
#  'concerns': 9,
#  'centred': 1,
#  'coal': 7,
#  'beef': 57,
#  'significant': 34,
#  'country': 103,
#  'meanwhile': 13,
#  'diplomatic': 10,
#  'manoeuvres': 1,
#  'solve': 5,
#  'stand': 14,
#  'off': 89,
#  'continue': 84,
#  'ruling': 30,
#  'liberal': 18,
#  'democratic': 17,
#  'party': 34,
#  'yesterday': 161,
#  'outlined': 12,
#  'package': 34,
#  'measures': 67,
#  'economy': 125,
#  'proposed': 106,
#  'include': 65,
#  'large': 70,
#  'supplementary': 5,
#  'budget': 117,
#  'record': 188,
#  'public': 84,
#  'works': 12,
#  'spending': 54,
#  'first': 447,
#  'half': 113,
#  'financial': 148,
#  'call': 28,
#  'stepped': 2,
#  'an': 844,
#  'emergency': 10,
#  'measure': 16,
#  'stimulate': 27,
#  'despite': 71,
#  'prime': 73,
#  'yasuhiro': 12,
#  'nakasone': 24,
#  'avowed': 1,
#  'fiscal': 90,
#  'reform': 31,
#  'program': 66,
#  'deputy': 16,
#  'representative': 19,
#  'michael': 12,
#  'smith': 12,
#  'makoto': 3,
#  'kuroda': 9,
#  'international': 221,
#  'miti': 17,
#  'due': 160,
#  'meet': 63,
#  'washington': 92,
#  'week': 334,
#  'effort': 31,
#  'end': 275,
#  'china': 106,
#  'daily': 65,
#  'says': 143,
#  'vermin': 2,
#  'eat': 2,
#  'grain': 130,
#  'stocks': 177,
#  'survey': 8,
#  'provinces': 6,
#  'seven': 147,
#  'cities': 4,
#  'showed': 48,
#  'consume': 3,
#  'each': 119,
#  'tonnes': 535,
#  'or': 553,
#  'fruit': 3,
#  'output': 107,
#  'left': 28,
#  'rot': 3,
#  'its': 1372,
#  'vegetables': 4,
#  'paper': 27,
#  'blamed': 7,
#  'waste': 14,
#  'inadequate': 10,
#  'storage': 18,
#  'bad': 6,
#  'preservation': 2,
#  'methods': 6,
#  'launched': 20,
#  'national': 197,
#  'programme': 13,
#  'reduce': 77,
#  'calling': 10,
#  'improved': 41,
#  'technology': 40,
#  'greater': 23,
#  'production': 289,
#  'additives': 2,
#  'gave': 44,
#  'no': 277,
#  'details': 57,
#  'revise': 8,
#  'energy': 93,
#  'demand': 177,
#  'downwards': 4,
#  'ministry': 108,
#  'supply': 158,
#  'outlook': 28,
#  'august': 39,
#  'forecast': 96,
#  'downtrend': 2,
#  'expected': 274,
#  'lower': 152,
#  'projection': 6,
#  'primary': 26,
#  'supplies': 60,
#  'kilolitres': 1,
#  'kl': 2,
#  'decision': 70,
#  'follows': 45,
#  'emergence': 1,
#  'structural': 8,
#  'changes': 43,
#  'following': 75,
#  'rise': 240,
#  'value': 106,
#  'yen': 193,
#  'decline': 74,
#  'domestic': 164,
#  'power': 30,
#  'planning': 24,
#  'work': 40,
#  'out': 148,
#  'revised': 45,
#  'through': 120,
#  'deliberations': 1,
#  'committee': 74,
#  'meetings': 29,
#  'agency': 38,
#  'natural': 50,
#  'resources': 43,
#  'review': 36,
#  'breakdown': 8,
#  'including': 101,
#  'oil': 586,
#  'nuclear': 2,
#  'gas': 158,
#  'provided': 25,
#  'bulk': 17,
#  'ended': 144,
#  'march': 315,
#  'supplying': 5,
#  'estimated': 105,
#  'kilowatt': 1,
#  'hour': 10,
#  'basis': 70,
#  'followed': 23,
#  'liquefied': 3,
#  'noted': 61,
#  'thai': 15,
#  'deficit': 213,
#  'widens': 3,
#  'quarter': 377,
#  'thailand': 27,
#  'widened': 6,
#  'baht': 3,
#  'ago': 129,
#  'economics': 9,
#  'department': 183,
#  'janunary': 1,
#  'rose': 227,
#  'climate': 4,
#  'resulted': 20,
#  'increase': 221,
#  'raw': 20,
#  'materials': 45,
#  'semi': 12,
#  'finished': 8,
#  'bill': 70,
#  'however': 137,
#  'fell': 126,
#  'prices': 387,
#  'expanded': 7,
#  'growth': 258,
#  'smaller': 17,
#  'than': 366,
#  'earnings': 177,
#  'key': 51,
#  'commodities': 30,
#  'rice': 72,
#  'declined': 61,
#  'maize': 41,
#  'sugar': 130,
#  'tin': 51,
#  'canned': 4,
#  'pineapples': 1,
#  'registering': 3,
#  'high': 150,
#  'were': 597,
#  'jewellery': 1,
#  'clothing': 4,
#  'rubber': 36,
#  'indonesia': 46,
#  'sees': 76,
#  'cpo': 5,
#  'price': 397,
#  'rising': 73,
#  'sharply': 46,
#  'expects': 98,
#  'crude': 160,
#  'palm': 32,
#  'tonne': 75,
#  'fob': 14,
#  'sometime': 3,
#  'better': 41,
#  'european': 121,
#  'fall': 111,
#  'malaysian': 11,
#  'hasrul': 1,
#  'harahap': 3,
#  'junior': 4,
#  'tree': 2,
#  'crops': 33,
#  'indonesian': 10,
#  'reporters': 47,
#  'sumatran': 1,
#  'now': 173,
#  'around': 164,
#  'cif': 7,
#  'delivery': 58,
#  'rotterdam': 13,
#  'traders': 133,
#  'maintain': 37,
#  'making': 73,
#  'recent': 102,
#  'purchases': 33,
#  'so': 103,
#  'possibly': 19,
#  'second': 82,
#  'producer': 59,
#  'after': 367,
#  'forced': 16,
#  'ensure': 9,
#  'during': 110,
#  'moslem': 1,
#  'fasting': 2,
#  'month': 250,
#  'ramadan': 2,
#  'cover': 28,
#  'temporary': 24,
#  'shortage': 20,
#  'lose': 7,
#  'calendar': 18,
#  'according': 54,
#  'central': 193,
#  'bank': 616,
#  'figures': 118,
#  'ship': 16,
#  'ban': 21,
#  'ends': 15,
#  'nsw': 10,
#  'ports': 18,
#  'tug': 5,
#  'crews': 3,
#  'wales': 5,
#  'victoria': 3,
#  'western': 68,
#  'lifted': 15,
#  'flag': 9,
#  'ships': 36,
#  'carrying': 12,
#  'containers': 2,
#  'still': 112,
#  'being': 97,
#  'disrupted': 7,
#  'separate': 19,
#  'shipping': 25,
#  'imposed': 26,
#  'pay': 151,
#  'claim': 8,
#  'prevented': 7,
#  'movement': 20,
#  'port': 50,
#  'nearly': 34,
#  'vessels': 20,
#  'went': 25,
#  'before': 141,
#  'hearing': 14,
#  'arbitration': 3,
#  'commission': 111,
#  'today': 275,
#  'disruption': 3,
#  'began': 46,
#  'cargo': 20,
#  'handling': 8,
#  'sydney': 5,
#  'newcastle': 3,
#  'kembla': 3,
#  'part': 96,
#  'called': 62,
#  'trades': 14,
#  'labour': 15,
#  'council': 58,
#  'protest': 9,
#  'state': 112,
#  'workers': 54,
#  'compensation': 12,
#  'laws': 14,
#  'various': 19,
#  'unions': 11,
#  'appear': 16,
#  'taking': 38,
#  'turn': 12,
#  'start': 100,
#  'shift': 10,
#  'then': 42,
#  'walk': 1,
#  'container': 4,
#  'movements': 9,
#  'most': 108,
#  'affected': 39,
#  'stopped': 9,
#  'altogether': 4,
#  'say': 97,
#  'how': 41,
#  'go': 43,
#  'what': 77,
#  'effect': 45,
#  'commodity': 49,
#  'may': 540,
#  'likely': 106,
#  'least': 45,
#  'paian': 1,
#  'nainggolan': 3,
#  'reuters': 92,
#  'telephone': 24,
#  'interview': 22,
#  'sawn': 1,
#  'timber': 5,
#  'pepper': 1,
#  'tobacco': 19,
#  'considered': 21,
#  'either': 22,
#  'refined': 23,
#  'introduced': 23,
#  'question': 19,
#  'rachmat': 1,
#  'saleh': 2,
#  'when': 169,
#  'ahead': 28,
#  'made': 174,
#  'fledgling': 1,
#  'currently': 57,
#  'coffee': 71,
#  'physicals': 3,
#  'outcry': 1,
#  'system': 102,
#  'four': 168,
#  'days': 128,
#  'several': 82,
#  'factors': 31,
#  'make': 91,
#  'cautiously': 2,
#  'slowly': 7,
#  'safely': 1,
#  'mistake': 2,
#  'undermine': 5,
#  'confidence': 21,
#  'physical': 9,
#  'added': 219,
#  'january': 106,
#  'contracts': 42,
#  'traded': 27,
#  'five': 245,
#  'forward': 29,
#  'robusta': 2,
#  'grades': 16,
#  'prompt': 2,
#  'board': 184,
#  'considering': 32,
#  'introduction': 10,
#  'futures': 64,
#  'later': 55,
#  'feasibility': 3,
#  'study': 28,
#  'needed': 50,
#  'decisions': 13,
#  'until': 62,
#  'elections': 6,
#  'monday': 25,
#  'should': 146,
#  'marketing': 72,
#  'hoped': 14,
#  'development': 89,
#  'help': 80,
#  'trying': 26,
#  'overseas': 25,
#  'building': 42,
#  'contacts': 5,
#  'users': 7,
#  'teams': 1,
#  'already': 82,
#  'encourage': 17,
#  'direct': 15,
#  'use': 119,
#  'delegation': 9,
#  'visit': 17,
#  'europe': 45,
#  'mexico': 22,
#  'latin': 4,
#  'states': 145,
#  'participation': 7,
#  'infant': 1,
#  'good': 71,
#  'although': 66,
#  'disappointing': 4,
#  'transactions': 24,
#  'december': 89,
#  'totalled': 26,
#  'worth': 51,
#  'plus': 32,
#  'rupiah': 3,
#  'delivered': 9,
#  'locally': 2,
#  'latest': 66,
#  'report': 209,
#  'amounted': 6,
#  'only': 175,
#  'lots': 4,
#  'valued': 15,
#  'total': 293,
#  'membership': 8,
#  'nine': 111,
#  'brokers': 25,
#  'sri': 14,
#  'lanka': 13,
#  'gets': 11,
#  'usda': 108,
#  'approval': 65,
#  'wheat': 189,
#  'food': 52,
#  'agriculture': 130,
#  'approved': 64,
#  'continental': 25,
#  'sale': 147,
#  'soft': 23,
#  'c': 76,
#  'f': 52,
#  'pacific': 39,
#  'northwest': 10,
#  'colombo': 6,
#  'shipment': 32,
#  'mining': 40,
#  'gold': 99,
#  'mine': 50,
#  'corp': 623,
#  'holdings': 56,
#  'wmng': 2,
#  'wmc': 6,
#  'establish': 5,
#  'joint': 55,
#  'venture': 46,
#  'northern': 19,
#  'territory': 2,
#  'about': 515,
#  'known': 23,
#  'goodall': 1,
#  'project': 14,
#  'owned': 125,
#  'local': 53,
#  'w': 17,
#  'r': 17,
#  'grace': 11,
#  'gra': 3,
#  'unit': 171,
#  'located': 15,
#  'kms': 2,
#  'east': 52,
#  'adelaide': 1,
#  'river': 23,
#  'mt': 11,
#  'bundey': 1,
#  'statement': 168,
#  'pit': 2,
#  'conventional': 3,
#  'leach': 1,
#  'treatment': 9,
#  'plant': 66,
#  'produce': 28,
#  'ounces': 17,
#  'mid': 26,
#  'annual': 101,
#  'ore': 24,
#  'capacity': 42,
#  'sumitomo': 16,
#  'aims': 6,
#  'quick': 7,
#  'recovery': 25,
#  'merger': 128,
#  'sumi': 1,
#  'certain': 63,
#  'status': 15,
#  'profitable': 21,
#  'result': 86,
#  'heiwa': 4,
#  'sogo': 4,
#  'analysts': 185,
#  'osaka': 2,
#  'based': 142,
#  'desposits': 1,
#  'trillion': 4,
#  'merged': 6,
#  'small': 40,
#  'struggling': 3,
#  'unrecoverable': 1,
#  'loans': 118,
#  'october': 53,
#  'link': 14,
#  'president': 137,
#  'koh': 1,
#  'komatsu': 9,
#  'confident': 9,
#  'his': 105,
#  'can': 116,
#  'regain': 1,
#  'position': 67,
#  'll': 4,
#  'back': 50,
#  'within': 63,
#  'three': 277,
#  'years': 159,
#  'initially': 8,
#  'profitability': 5,
#  'efficiency': 8,
#  'vastly': 1,
#  'branch': 10,
#  'network': 18,
#  'metropolitan': 4,
#  'area': 61,
#  'relatively': 16,
#  'weak': 24,
#  'divided': 9,
#  'whether': 52,
#  'gamble': 3,
#  'paid': 65,
#  'too': 53,
#  'debts': 4,
#  'others': 18,
#  'argue': 4,
#  'effective': 91,
#  'creating': 1,
#  'comparable': 10,
#  'scratch': 1,
#  'agreed': 155,
#  'aggressive': 8,
#  'entered': 32,
#  'lucrative': 4,
#  'securities': 151,
#  'geared': 2,
#  'competition': 21,
#  'questioned': 4,
#  'wisdom': 1,
#  'moves': 36,
#  've': 14,
#  'bold': 3,
#  'everything': 3,
#  'largely': 15,
#  'hands': 11,
#  'kleinwort': 5,
#  'benson': 2,
#  'simon': 3,
#  'smithson': 2,
#  'limits': 21,
#  'placed': 18,
#  'enter': 8,
#  'investment': 161,
#  'goldman': 5,
#  'sachs': 5,
#  'limited': 34,
#  'partnership': 30,
#  'federal': 145,
#  'reserve': 109,
#  'forbidden': 1,
#  'personnel': 7,
#  'tie': 4,
#  'widely': 7,
#  'looked': 5,
#  'lame': 1,
#  'duck': 1,
#  'fed': 165,
#  'stricter': 1,
#  'regulations': 12,
#  'change': 80,
#  'near': 41,
#  'future': 51,
#  'things': 7,
#  'wait': 4,
#  'st': 281,
#  'century': 13,
#  'willing': 13,
#  'patient': 4,
#  'routes': 7,
#  'into': 186,
#  'home': 43,
#  'article': 8,
#  'act': 32,
#  'version': 3,
#  'glass': 3,
#  'steagall': 1,
#  'separates': 2,
#  'banking': 54,
#  'walls': 1,
#  'crumbling': 1,
#  'hopes': 21,
#  'deregulation': 10,
#  'create': 7,
#  'opportunities': 12,
#  'need': 49,
#  'find': 22,
#  'chances': 5,
#  'cases': 12,
#  'these': 87,
#  'related': 28,
#  'trust': 56,
#  'occur': 10,
#  'focus': 16,
#  'bond': 50,
#  'dealing': 3,
#  'strengthening': 10,
#  'meiko': 1,
#  'holds': 32,
#  'optimistic': 18,
#  'entering': 8,
#  'here': 67,
#  'swiss': 40,
#  'universal': 8,
#  'subsidiary': 132,
#  'banca': 1,
#  'del': 9,
#  'gottardo': 2,
#  'finance': 112,
#  'grant': 6,
#  'licences': 12,
#  'subsidiaries': 19,
#  'banks': 149,
#  'soon': 36,
#  'parent': 26,
#  'less': 91,
#  'reluctant': 9,
#  'push': 14,
#  'don': 40,
#  'waves': 1,
#  'expect': 49,
#  'allowed': 22,
#  'like': 37,
#  'city': 38,
#  'pushing': 7,
#  'lending': 19,
#  'individuals': 8,
#  'medium': 27,
#  'businesses': 49,
#  'replace': 9,
#  'disappearing': 1,
#  'big': 15,
#  'devote': 1,
#  'lot': 16,
#  'digesting': 1,
#  'initiatives': 5,
#  'ailing': 3,
#  'strategies': 2,
#  'absorbing': 1,
#  'juggling': 1,
#  'next': 155,
#  'decade': 5,
#  'see': 58,
#  'strategy': 25,
#  'right': 33,
#  'wrong': 4,
#  'subroto': 3,
#  'supports': 6,
#  'extension': 24,
#  'mines': 25,
#  'confirmed': 22,
#  'support': 71,
#  'sixth': 10,
#  'agreement': 258,
#  'ita': 7,
#  'necessary': 24,
#  'clarify': 2,
#  'lapse': 2,
#  'ready': 15,
#  'seventh': 7,
#  'accord': 60,
#  'believe': 41,
#  'unnecessary': 2,
#  'expire': 17,
#  'june': 238,
#  'unless': 28,
#  'thirds': 5,
#  'majority': 24,
#  'members': 49,
#  'vote': 18,
#  'bundesbank': 84,
#  'allocates': 2,
#  'marks': 82,
#  'tender': 147,
#  'accepted': 23,
#  'bids': 33,
#  'repurchase': 49,
#  'fixed': 47,
#  'rate': 379,
#  ...}

# %%
# Calculate probabilities
trigram_probabilities = defaultdict(lambda: defaultdict(lambda: 0))
for prefix, suffixes in trigram_counts.items():
    total_count = sum(suffixes.values())
    for suffix, count in suffixes.items():
        trigram_probabilities[prefix][suffix] = count / total_count

# %%
# find the overall frequency of words in the corpus
counts = Counter(unigram_dict)
counts
# Out:
# Counter({'the': 12496,
#          'of': 6671,
#          'to': 6337,
#          'in': 5070,
#          'said': 4649,
#          'and': 4599,
#          'a': 4412,
#          'mln': 3064,
#          's': 2864,
#          'for': 2592,
#          'vs': 2269,
#          'dlrs': 2140,
#          'it': 1970,
#          'pct': 1811,
#          'on': 1643,
#          'lt': 1498,
#          'is': 1420,
#          'that': 1376,
#          'by': 1375,
#          'its': 1372,
#          'from': 1369,
#          'at': 1311,
#          'cts': 1232,
#          'year': 1212,
#          'be': 1165,
#          'with': 1127,
#          'was': 1127,
#          'u': 1117,
#          'billion': 1112,
#          'net': 1098,
#          'will': 984,
#          'has': 974,
#          'he': 971,
#          'would': 926,
#          'as': 884,
#          'an': 844,
#          'company': 843,
#          'not': 838,
#          'inc': 723,
#          'last': 654,
#          'but': 650,
#          'which': 643,
#          'this': 642,
#          'are': 625,
#          'corp': 623,
#          'shr': 622,
#          'bank': 616,
#          'loss': 607,
#          'were': 597,
#          'oil': 586,
#          'or': 553,
#          'trade': 549,
#          'have': 542,
#          'may': 540,
#          'tonnes': 535,
#          'they': 518,
#          'share': 516,
#          'about': 515,
#          'had': 512,
#          'one': 508,
#          'shares': 499,
#          'market': 498,
#          'april': 477,
#          'new': 474,
#          'qtr': 463,
#          'first': 447,
#          'two': 444,
#          'also': 442,
#          'japan': 441,
#          'price': 397,
#          'been': 396,
#          'stock': 394,
#          'prices': 387,
#          'up': 386,
#          'nil': 386,
#          'rate': 379,
#          'quarter': 377,
#          'sales': 371,
#          'co': 370,
#          'after': 367,
#          'than': 366,
#          'per': 366,
#          'dollar': 358,
#          'more': 354,
#          'profit': 350,
#          'group': 342,
#          'week': 334,
#          'other': 331,
#          'offer': 320,
#          'march': 315,
#          'government': 304,
#          'o': 296,
#          'exports': 294,
#          'total': 293,
#          'could': 291,
#          'production': 289,
#          'revs': 289,
#          'rates': 285,
#          'if': 282,
#          'st': 281,
#          'exchange': 279,
#          'some': 278,
#          'no': 277,
#          'three': 277,
#          'end': 275,
#          'today': 275,
#          'tax': 275,
#          'expected': 274,
#          'ltd': 273,
#          'against': 270,
#          'note': 268,
#          'all': 261,
#          'we': 258,
#          'growth': 258,
#          'agreement': 258,
#          'foreign': 253,
#          'interest': 252,
#          'month': 250,
#          'five': 245,
#          'economic': 244,
#          'imports': 242,
#          'rise': 240,
#          'current': 240,
#          'june': 238,
#          'told': 237,
#          'under': 237,
#          'over': 236,
#          'there': 234,
#          'their': 230,
#          'dlr': 230,
#          'rose': 227,
#          'international': 221,
#          'increase': 221,
#          'added': 219,
#          'because': 214,
#          'deficit': 213,
#          'west': 212,
#          'stg': 210,
#          'report': 209,
#          'major': 206,
#          'cut': 206,
#          'acquisition': 204,
#          'products': 200,
#          'industry': 200,
#          'national': 197,
#          'six': 197,
#          'yen': 193,
#          'central': 193,
#          'japanese': 192,
#          'between': 191,
#          'february': 191,
#          'companies': 191,
#          'officials': 190,
#          'wheat': 189,
#          'record': 188,
#          'meeting': 187,
#          'into': 186,
#          'analysts': 185,
#          'board': 184,
#          'department': 183,
#          'markets': 182,
#          'money': 180,
#          'ec': 178,
#          'stocks': 177,
#          'demand': 177,
#          'earnings': 177,
#          'only': 175,
#          'united': 175,
#          'official': 174,
#          'made': 174,
#          'now': 173,
#          'further': 172,
#          'higher': 172,
#          'business': 171,
#          'unit': 171,
#          'when': 169,
#          'four': 168,
#          'statement': 168,
#          'cash': 168,
#          'world': 166,
#          'spokesman': 166,
#          'avg': 166,
#          'fed': 165,
#          'while': 164,
#          'months': 164,
#          'domestic': 164,
#          'around': 164,
#          'shrs': 164,
#          'earlier': 162,
#          'assets': 162,
#          'sources': 161,
#          'yesterday': 161,
#          'investment': 161,
#          'due': 160,
#          'crude': 160,
#          'years': 159,
#          'supply': 158,
#          'gas': 158,
#          'average': 158,
#          'since': 158,
#          'reported': 157,
#          'period': 157,
#          'surplus': 155,
#          'agreed': 155,
#          'next': 155,
#          'compared': 155,
#          'p': 155,
#          'reserves': 153,
#          'canada': 153,
#          'currency': 153,
#          'export': 152,
#          'lower': 152,
#          'buy': 152,
#          'pay': 151,
#          'securities': 151,
#          'common': 151,
#          'high': 150,
#          'banks': 149,
#          'financial': 148,
#          'out': 148,
#          'policy': 148,
#          'stake': 148,
#          'plan': 148,
#          'seven': 147,
#          'sale': 147,
#          'tender': 147,
#          'should': 146,
#          'time': 145,
#          'chairman': 145,
#          'states': 145,
#          'federal': 145,
#          'shareholders': 145,
#          'canadian': 145,
#          'ended': 144,
#          'says': 143,
#          'any': 142,
#          'countries': 142,
#          'based': 142,
#          'trading': 141,
#          'before': 141,
#          'sell': 139,
#          'down': 138,
#          'i': 138,
#          'however': 137,
#          'president': 137,
#          'bid': 137,
#          'dividend': 136,
#          'dome': 136,
#          'south': 135,
#          'credit': 135,
#          'debt': 135,
#          'take': 134,
#          'traders': 133,
#          'day': 132,
#          'subsidiary': 132,
#          'grain': 130,
#          'sugar': 130,
#          'agriculture': 130,
#          'operations': 130,
#          'crop': 130,
#          'ago': 129,
#          'days': 128,
#          'merger': 128,
#          'includes': 127,
#          'announced': 127,
#          'american': 126,
#          'fell': 126,
#          'economy': 125,
#          'owned': 125,
#          'dealers': 125,
#          'did': 123,
#          'income': 123,
#          'minister': 122,
#          'management': 122,
#          'european': 121,
#          'acquire': 121,
#          'term': 120,
#          'industrial': 120,
#          'through': 120,
#          'long': 119,
#          'each': 119,
#          'use': 119,
#          'figures': 118,
#          'loans': 118,
#          'industries': 118,
#          'budget': 117,
#          'monetary': 117,
#          'can': 116,
#          'loan': 116,
#          't': 115,
#          'firm': 114,
#          'prior': 114,
#          'oper': 114,
#          'half': 113,
#          'capital': 113,
#          'talks': 112,
#          'still': 112,
#          'state': 112,
#          'finance': 112,
#          'fall': 111,
#          'commission': 111,
#          'nine': 111,
#          'terms': 111,
#          'during': 110,
#          'plans': 110,
#          'july': 110,
#          'reserve': 109,
#          'ministry': 108,
#          'most': 108,
#          'usda': 108,
#          'held': 108,
#          'output': 107,
#          'acquired': 107,
#          'proposed': 106,
#          'china': 106,
#          'value': 106,
#          'likely': 106,
#          'january': 106,
#          'purchase': 106,
#          'estimated': 105,
#          'his': 105,
#          'country': 103,
#          'so': 103,
#          'k': 103,
#          'non': 103,
#          'union': 103,
#          'recent': 102,
#          'system': 102,
#          'inflation': 102,
#          'data': 102,
#          'outstanding': 102,
#          'move': 101,
#          'gain': 101,
#          'our': 101,
#          'including': 101,
#          'annual': 101,
#          'sold': 101,
#          'such': 100,
#          'start': 100,
#          'eight': 100,
#          'gold': 99,
#          'german': 99,
#          'who': 98,
#          'open': 98,
#          'expects': 98,
#          'corn': 98,
#          'plc': 98,
#          'being': 97,
#          'say': 97,
#          'lead': 96,
#          'forecast': 96,
#          'part': 96,
#          'level': 96,
#          'operating': 95,
#          'full': 95,
#          'energy': 93,
#          'reagan': 93,
#          'much': 92,
#          'washington': 92,
#          'reuters': 92,
#          'results': 92,
#          'previously': 92,
#          'gulf': 92,
#          'adjusted': 92,
#          'make': 91,
#          'effective': 91,
#          'less': 91,
#          'both': 91,
#          'do': 90,
#          'fiscal': 90,
#          'well': 90,
#          'levels': 90,
#          'n': 90,
#          'set': 90,
#          'off': 89,
#          'development': 89,
#          'december': 89,
#          'another': 89,
#          'm': 89,
#          'petroleum': 89,
#          'same': 88,
#          'york': 88,
#          'proposal': 88,
#          'takeover': 88,
#          'texas': 88,
#          'short': 87,
#          'these': 87,
#          'farm': 87,
#          'cents': 87,
#          'consumer': 87,
#          'house': 87,
#          'computer': 87,
#          'cost': 86,
#          'general': 86,
#          'result': 86,
#          'issue': 85,
#          'previous': 85,
#          'bought': 85,
#          'strong': 85,
#          'mths': 85,
#          'continue': 84,
#          'public': 84,
#          'bundesbank': 84,
#          'profits': 84,
#          'account': 84,
#          'barrel': 84,
#          'cuts': 84,
#          'increased': 83,
#          'g': 83,
#          'tariffs': 82,
#          'action': 82,
#          'second': 82,
#          'several': 82,
#          'already': 82,
#          'marks': 82,
#          'div': 82,
#          'free': 82,
#          'intervention': 81,
#          'help': 80,
#          'change': 80,
#          'germany': 80,
#          'british': 80,
#          'largest': 79,
#          'opec': 79,
#          'revenues': 79,
#          'soybean': 78,
#          'contract': 78,
#          'reduce': 77,
#          'what': 77,
#          'sees': 76,
#          'c': 76,
#          'early': 76,
#          'amount': 76,
#          'tokyo': 75,
#          'those': 75,
#          'following': 75,
#          'tonne': 75,
#          'low': 75,
#          'pipeline': 75,
#          'asked': 74,
#          'decline': 74,
#          'committee': 74,
#          'losses': 74,
#          'services': 74,
#          'split': 74,
#          'chemical': 74,
#          'paris': 74,
#          'e': 74,
#          'preferred': 74,
#          'prime': 73,
#          'rising': 73,
#          'making': 73,
#          'funds': 73,
#          'weeks': 73,
#          'product': 73,
#          'season': 73,
#          'deposits': 73,
#          'subject': 72,
#          'possible': 72,
#          'producers': 72,
#          'very': 72,
#          'rice': 72,
#          'marketing': 72,
#          'community': 72,
#          'nations': 71,
#          'despite': 71,
#          'coffee': 71,
#          'good': 71,
#          'support': 71,
#          'fund': 71,
#          'raised': 70,
#          'large': 70,
#          'decision': 70,
#          'basis': 70,
#          'bill': 70,
#          'copper': 70,
#          'burlington': 70,
#          'goods': 69,
#          'brazil': 69,
#          'texaco': 69,
#          'western': 68,
#          'line': 68,
#          'given': 68,
#          'own': 68,
#          'received': 68,
#          'court': 68,
#          'costs': 68,
#          'import': 67,
#          'third': 67,
#          'measures': 67,
#          'position': 67,
#          'here': 67,
#          'does': 67,
#          'transaction': 67,
#          'french': 67,
#          'completed': 67,
#          'raises': 67,
#          'below': 66,
#          'program': 66,
#          'although': 66,
#          'latest': 66,
#          'plant': 66,
#          'seen': 66,
#          'l': 66,
#          'used': 66,
#          'balance': 66,
#          'cocoa': 66,
#          'x': 66,
#          'include': 65,
#          'daily': 65,
#          'approval': 65,
#          'paid': 65,
#          'b': 65,
#          'savings': 65,
#          'discount': 65,
#          'futures': 64,
#          'approved': 64,
#          'number': 64,
#          'little': 64,
#          'london': 64,
#          'reached': 64,
#          'th': 64,
#          'meet': 63,
#          'certain': 63,
#          'within': 63,
#          'available': 63,
#          'francs': 63,
#          'above': 63,
#          'sets': 63,
#          'raise': 63,
#          'lynch': 63,
#          'estimates': 62,
#          'taiwan': 62,
#          'called': 62,
#          'until': 62,
#          'show': 62,
#          'past': 62,
#          'close': 62,
#          'nd': 62,
#          'noted': 61,
#          'declined': 61,
#          'area': 61,
#          'rights': 61,
#          'france': 61,
#          'analyst': 60,
#          'where': 60,
#          'supplies': 60,
#          'accord': 60,
#          'range': 60,
#          'unchanged': 60,
#          'buying': 60,
#          'might': 59,
#          'pact': 59,
#          'put': 59,
#          'producer': 59,
#          'investors': 59,
#          'payments': 59,
#          'insurance': 59,
#          'merrill': 59,
#          'them': 58,
#          'delivery': 58,
#          'council': 58,
#          'see': 58,
#          'bankers': 58,
#          'economists': 58,
#          'special': 58,
#          'firms': 57,
#          'pressure': 57,
#          'partners': 57,
#          'beef': 57,
#          'details': 57,
#          'currently': 57,
#          'name': 57,
#          'control': 57,
#          'deal': 57,
#          'private': 57,
#          'ministers': 57,
#          'yield': 57,
#          'australian': 56,
#          'holdings': 56,
#          'trust': 56,
#          'drop': 56,
#          'treasury': 56,
#          'just': 56,
#          'financing': 56,
#          'systems': 56,
#          'warner': 56,
#          'far': 55,
#          'remain': 55,
#          'problems': 55,
#          'australia': 55,
#          'later': 55,
#          'joint': 55,
#          'holding': 55,
#          'bills': 55,
#          'planned': 55,
#          'point': 55,
#          'executive': 55,
#          'comment': 55,
#          'steel': 55,
#          'soviet': 55,
#          'qtly': 55,
#          'feb': 55,
#          'agreements': 55,
#          'currencies': 55,
#          'many': 54,
#          'spending': 54,
#          'according': 54,
#          'workers': 54,
#          'banking': 54,
#          'target': 54,
#          'sector': 54,
#          'september': 54,
#          'barrels': 54,
#          'continued': 54,
#          'borg': 54,
#          'association': 53,
#          'local': 53,
#          'october': 53,
#          'too': 53,
#          'america': 53,
#          'probably': 53,
#          'stability': 53,
#          'field': 53,
#          'without': 53,
#          'date': 53,
#          'transcanada': 53,
#          'oecd': 53,
#          'exporters': 52,
#          'impact': 52,
#          'food': 52,
#          'f': 52,
#          'east': 52,
#          'whether': 52,
#          'britain': 52,
#          'units': 52,
#          'dollars': 52,
#          'bpd': 52,
#          'news': 52,
#          'prev': 52,
#          'chief': 51,
#          'key': 51,
#          'tin': 51,
#          'worth': 51,
#          'future': 51,
#          'continuing': 51,
#          'late': 51,
#          'conditions': 51,
#          'offered': 51,
#          'think': 51,
#          'figure': 51,
#          'division': 51,
#          'yet': 51,
#          'harcourt': 51,
#          'natural': 50,
#          'port': 50,
#          'needed': 50,
#          'mine': 50,
#          'back': 50,
#          'bond': 50,
#          'restructuring': 50,
#          'exploration': 50,
#          'get': 50,
#          'dutch': 50,
#          'leading': 49,
#          'korea': 49,
#          'commodity': 49,
#          'need': 49,
#          'expect': 49,
#          'businesses': 49,
#          'members': 49,
#          'repurchase': 49,
#          'give': 49,
#          'secretary': 49,
#          'pretax': 49,
#          'saudi': 49,
#          'congress': 49,
#          'saying': 49,
#          'receive': 49,
#          'reduced': 49,
#          'cotton': 49,
#          'wk': 49,
#          'showed': 48,
#          'ending': 48,
#          'taken': 48,
#          'real': 48,
#          'issued': 48,
#          'mark': 48,
#          'announcement': 48,
#          'increases': 48,
#          'undisclosed': 48,
#          'reporters': 47,
#          'fixed': 47,
#          'manufacturing': 47,
#          'heavy': 47,
#          'recently': 47,
#          'de': 47,
#          'disclosed': 47,
#          'communique': 47,
#          'administration': 47,
#          'must': 46,
#          'indonesia': 46,
#          'sharply': 46,
#          'began': 46,
#          'venture': 46,
#          'farmers': 46,
#          'even': 46,
#          'research': 46,
#          'gaf': 46,
#          'gains': 46,
#          'boost': 45,
#          'produced': 45,
#          'follows': 45,
#          'revised': 45,
#          'materials': 45,
#          'effect': 45,
#          'least': 45,
#          'europe': 45,
#          'signed': 45,
#          'gasoline': 45,
#          'reduction': 45,
#          'information': 45,
#          'final': 45,
#          'rd': 45,
#          'investor': 45,
#          'way': 45,
#          'soybeans': 45,
#          'filing': 45,
#          'among': 44,
#          'office': 44,
#          'friday': 44,
#          'gave': 44,
#          'main': 44,
#          'conference': 44,
#          're': 44,
#          'index': 44,
#          'j': 44,
#          'payable': 44,
#          'fourth': 44,
#          'want': 43,
#          'changes': 43,
#          'resources': 43,
#          'go': 43,
#          'home': 43,
#          'manager': 43,
#          'become': 43,
#          'addition': 43,
#          'hold': 43,
#          'owns': 43,
#          'areas': 43,
#          'north': 43,
#          'series': 43,
#          'shipments': 43,
#          'offers': 43,
#          'buys': 43,
#          'additional': 43,
#          'smelter': 43,
#          'spot': 43,
#          'few': 42,
#          'selling': 42,
#          'then': 42,
#          'contracts': 42,
#          'building': 42,
#          'capacity': 42,
#          'rises': 42,
#          'growing': 42,
#          'scheduled': 42,
#          'sharp': 42,
#          'strike': 42,
#          'service': 42,
#          'associates': 42,
#          'credits': 42,
#          'present': 42,
#          'stores': 42,
#          'tons': 42,
#          'us': 41,
#          'commercial': 41,
#          'director': 41,
#          'improved': 41,
#          'maize': 41,
#          'better': 41,
#          'how': 41,
#          'near': 41,
#          'believe': 41,
#          'provide': 41,
#          'interests': 41,
#          'gnp': 41,
#          'seeking': 41,
#          'white': 41,
#          'd': 41,
#          'tomorrow': 41,
#          'slightly': 41,
#          'guilders': 41,
#          'bancorp': 41,
#          'monthly': 41,
#          'borrowings': 41,
#          'senior': 40,
#          'allow': 40,
#          'view': 40,
#          'technology': 40,
#          'work': 40,
#          'mining': 40,
#          'small': 40,
#          'swiss': 40,
#          'don': 40,
#          'security': 40,
#          'equity': 40,
#          'mainly': 40,
#          'top': 40,
#          'press': 40,
#          'substantial': 40,
#          'believed': 40,
#          'adding': 40,
#          'keep': 40,
#          'unemployment': 40,
#          'provision': 40,
#          'commerce': 40,
#          'speculation': 40,
#          'force': 40,
#          'wednesday': 40,
#          'eddie': 40,
#          'bbl': 40,
#          'concern': 39,
#          'august': 39,
#          'affected': 39,
#          'pacific': 39,
#          'led': 39,
#          'payment': 39,
#          'equipment': 39,
#          'acquisitions': 39,
#          'charge': 39,
#          'africa': 39,
#          'ccc': 39,
#          'crazy': 39,
#          'named': 38,
#          'agency': 38,
#          'taking': 38,
#          'city': 38,
#          'people': 38,
#          'base': 38,
#          'england': 38,
#          'gross': 38,
#          'iraq': 38,
#          'quota': 38,
#          'morning': 38,
#          'statistics': 38,
#          'predicted': 38,
#          'payout': 38,
#          'return': 38,
#          'light': 38,
#          'hit': 37,
#          'hard': 37,
#          'maintain': 37,
#          'like': 37,
#          'negotiations': 37,
#          'bonus': 37,
#          'limit': 37,
#          'overall': 37,
#          'decided': 37,
#          'san': 37,
#          'standard': 37,
#          'italy': 37,
#          'metal': 37,
#          'poehl': 37,
#          'makes': 37,
#          'letter': 37,
#          'postings': 37,
#          'gillette': 37,
#          'similar': 36,
#          'review': 36,
#          'rubber': 36,
#          'ships': 36,
#          'moves': 36,
#          'soon': 36,
#          'rather': 36,
#          'almost': 36,
#          'add': 36,
#          'political': 36,
#          'situation': 36,
#          'imf': 36,
#          'baker': 36,
#          'dominion': 36,
#          'allied': 36,
#          'barley': 36,
#          'shell': 36,
#          'institutes': 36,
#          'electric': 35,
#          'slow': 35,
#          'spain': 35,
#          'included': 35,
#          'order': 35,
#          'economist': 35,
#          'kuwait': 35,
#          'monier': 35,
#          'expansion': 35,
#          'remaining': 35,
#          'begin': 35,
#          'seasonally': 35,
#          'cominco': 35,
#          'significant': 34,
#          'party': 34,
#          'package': 34,
#          'nearly': 34,
#          'limited': 34,
#          'octane': 34,
#          'buyers': 34,
#          'quoted': 34,
#          'response': 34,
#          'caused': 34,
#          'newspaper': 34,
#          'saw': 34,
#          'morgan': 34,
#          'meal': 34,
#          'she': 34,
#          'orange': 34,
#          'lawson': 34,
#          'commitments': 34,
#          'csr': 34,
#          'stcks': 34,
#          'james': 33,
#          'crops': 33,
#          'purchases': 33,
#          'right': 33,
#          'bids': 33,
#          'started': 33,
#          'properties': 33,
#          'pre': 33,
#          'life': 33,
#          'turnover': 33,
#          'head': 33,
#          'cooperation': 33,
#          'stable': 33,
#          'sells': 33,
#          'zealand': 33,
#          'opened': 33,
#          'directors': 33,
#          'again': 33,
#          'revenue': 33,
#          'initial': 33,
#          'offset': 33,
#          'louvre': 33,
#          'ldp': 33,
#          'independent': 33,
#          'excludes': 33,
#          'buyout': 33,
#          'buffer': 33,
#          'meat': 33,
#          'consumers': 33,
#          'textile': 32,
#          'palm': 32,
#          'considering': 32,
#          'plus': 32,
#          'shipment': 32,
#          'entered': 32,
#          'act': 32,
#          'holds': 32,
#          'quotas': 32,
#          'potential': 32,
#          'particularly': 32,
#          'corporation': 32,
#          'arabia': 32,
#          'lost': 32,
#          'calls': 32,
#          'estimate': 32,
#          'form': 32,
#          'increasing': 32,
#          'senate': 32,
#          'working': 32,
#          'privately': 32,
#          'round': 32,
#          'ecuador': 32,
#          'policies': 32,
#          'summit': 32,
#          'feed': 32,
#          'oils': 32,
#          'able': 31,
#          'place': 31,
#          'reform': 31,
#          'effort': 31,
#          'factors': 31,
#          'reflect': 31,
#          'consolidated': 31,
#          'war': 31,
#          'institute': 31,
#          'operate': 31,
#          'sanctions': 31,
#          'singapore': 31,
#          'reason': 31,
#          'november': 31,
#          'discussions': 31,
#          'process': 31,
#          'lire': 31,
#          'quarterly': 31,
#          'diluted': 31,
#          'immediately': 31,
#          'communications': 31,
#          'definitive': 31,
#          'ct': 31,
#          'projected': 31,
#          'customers': 31,
#          ...})

# %%
# vocabulary size
total_count = len(unigram_dict)
total_count
# Out:
# 12579

# %%
# relative frequencies of each word
for word in counts:
    counts[word] /= float(total_count)

counts
# Out:
# Counter({'the': 0.9934017012481119,
#          'of': 0.530328324986088,
#          'to': 0.5037761348278877,
#          'in': 0.40305270689243977,
#          'said': 0.36958422768105575,
#          'and': 0.3656093489148581,
#          'a': 0.35074330232927897,
#          'mln': 0.24358057079259082,
#          's': 0.2276810557278003,
#          'for': 0.2060577152396852,
#          'vs': 0.18037999841004848,
#          'dlrs': 0.17012481119325862,
#          'it': 0.15661022338818667,
#          'pct': 0.1439701089116782,
#          'on': 0.13061451625725415,
#          'lt': 0.11908736783528102,
#          'is': 0.11288655696001272,
#          'that': 0.1093886636457588,
#          'by': 0.10930916607043485,
#          'its': 0.10907067334446299,
#          'from': 0.10883218061849113,
#          'at': 0.10422132124970189,
#          'cts': 0.09794101279910963,
#          'year': 0.09635106129263057,
#          'be': 0.0926146752524048,
#          'with': 0.0895937673900946,
#          'was': 0.0895937673900946,
#          'u': 0.08879879163685507,
#          'billion': 0.08840130376023532,
#          'net': 0.08728833770569998,
#          'will': 0.07822561411876938,
#          'has': 0.07743063836552985,
#          'he': 0.077192145639558,
#          'would': 0.07361475474998012,
#          'as': 0.07027585658637411,
#          'an': 0.06709595357341601,
#          'company': 0.06701645599809206,
#          'not': 0.06661896812147229,
#          'inc': 0.05747674695921774,
#          'last': 0.051991414261865015,
#          'but': 0.051673423960569204,
#          'which': 0.05111694093330153,
#          'this': 0.05103744335797758,
#          'are': 0.049685984577470386,
#          'corp': 0.04952698942682248,
#          'shr': 0.04944749185149853,
#          'bank': 0.04897050639955482,
#          'loss': 0.04825502822163924,
#          'were': 0.04746005246839971,
#          'oil': 0.046585579139836235,
#          'or': 0.0439621591541458,
#          'trade': 0.04364416885284999,
#          'have': 0.04308768582558232,
#          'may': 0.04292869067493441,
#          'tonnes': 0.042531202798314655,
#          'they': 0.041179744017807454,
#          'share': 0.04102074886715955,
#          'about': 0.0409412512918356,
#          'had': 0.04070275856586374,
#          'one': 0.04038476826456793,
#          'shares': 0.039669290086652355,
#          'market': 0.0395897925113284,
#          'april': 0.0379203434295254,
#          'new': 0.037681850703553545,
#          'qtr': 0.03680737737499006,
#          'first': 0.03553541616980682,
#          'two': 0.03529692344383496,
#          'also': 0.03513792829318706,
#          'japan': 0.035058430717863104,
#          'price': 0.03156053740360919,
#          'been': 0.031481039828285234,
#          'stock': 0.031322044677637335,
#          'prices': 0.030765561650369665,
#          'up': 0.03068606407504571,
#          'nil': 0.03068606407504571,
#          'rate': 0.030129581047778044,
#          'quarter': 0.02997058589713014,
#          'sales': 0.02949360044518642,
#          'co': 0.029414102869862468,
#          'after': 0.029175610143890612,
#          'than': 0.02909611256856666,
#          'per': 0.02909611256856666,
#          'dollar': 0.02846013196597504,
#          'more': 0.028142141664679227,
#          'profit': 0.027824151363383415,
#          'group': 0.027188170760791795,
#          'week': 0.026552190158200175,
#          'other': 0.026313697432228316,
#          'offer': 0.025439224103664837,
#          'march': 0.025041736227045076,
#          'government': 0.024167262898481597,
#          'o': 0.023531282295889976,
#          'exports': 0.02337228714524207,
#          'total': 0.023292789569918117,
#          'could': 0.02313379441927021,
#          'production': 0.022974799268622306,
#          'revs': 0.022974799268622306,
#          'rates': 0.022656808967326497,
#          'if': 0.02241831624135464,
#          'st': 0.022338818666030685,
#          'exchange': 0.02217982351538278,
#          'some': 0.02210032594005883,
#          'no': 0.022020828364734877,
#          'three': 0.022020828364734877,
#          'end': 0.02186183321408697,
#          'today': 0.02186183321408697,
#          'tax': 0.02186183321408697,
#          'expected': 0.021782335638763018,
#          'ltd': 0.021702838063439065,
#          'against': 0.021464345337467206,
#          'note': 0.0213053501868193,
#          'all': 0.020748867159551633,
#          'we': 0.020510374433579774,
#          'growth': 0.020510374433579774,
#          'agreement': 0.020510374433579774,
#          'foreign': 0.020112886556960013,
#          'interest': 0.02003338898163606,
#          'month': 0.019874393830988154,
#          'five': 0.019476905954368393,
#          'economic': 0.01939740837904444,
#          'imports': 0.019238413228396534,
#          'rise': 0.019079418077748628,
#          'current': 0.019079418077748628,
#          'june': 0.018920422927100722,
#          'told': 0.018840925351776772,
#          'under': 0.018840925351776772,
#          'over': 0.01876142777645282,
#          'there': 0.018602432625804913,
#          'their': 0.0182844423245091,
#          'dlr': 0.0182844423245091,
#          'rose': 0.018045949598537246,
#          'international': 0.01756896414659353,
#          'increase': 0.01756896414659353,
#          'added': 0.017409968995945622,
#          'because': 0.01701248111932586,
#          'deficit': 0.016932983544001908,
#          'west': 0.016853485968677955,
#          'stg': 0.01669449081803005,
#          'report': 0.016614993242706096,
#          'major': 0.01637650051673424,
#          'cut': 0.01637650051673424,
#          'acquisition': 0.016217505366086335,
#          'products': 0.015899515064790523,
#          'industry': 0.015899515064790523,
#          'national': 0.015661022338818668,
#          'six': 0.015661022338818668,
#          'yen': 0.015343032037522856,
#          'central': 0.015343032037522856,
#          'japanese': 0.015263534462198903,
#          'between': 0.01518403688687495,
#          'february': 0.01518403688687495,
#          'companies': 0.01518403688687495,
#          'officials': 0.015104539311550997,
#          'wheat': 0.015025041736227046,
#          'record': 0.014945544160903093,
#          'meeting': 0.01486604658557914,
#          'into': 0.014786549010255187,
#          'analysts': 0.014707051434931234,
#          'board': 0.014627553859607283,
#          'department': 0.01454805628428333,
#          'markets': 0.014468558708959377,
#          'money': 0.01430956355831147,
#          'ec': 0.014150568407663567,
#          'stocks': 0.014071070832339614,
#          'demand': 0.014071070832339614,
#          'earnings': 0.014071070832339614,
#          'only': 0.013912075681691708,
#          'united': 0.013912075681691708,
#          'official': 0.013832578106367757,
#          'made': 0.013832578106367757,
#          'now': 0.013753080531043804,
#          'further': 0.01367358295571985,
#          'higher': 0.01367358295571985,
#          'business': 0.013594085380395898,
#          'unit': 0.013594085380395898,
#          'when': 0.013435090229747993,
#          'four': 0.01335559265442404,
#          'statement': 0.01335559265442404,
#          'cash': 0.01335559265442404,
#          'world': 0.013196597503776135,
#          'spokesman': 0.013196597503776135,
#          'avg': 0.013196597503776135,
#          'fed': 0.013117099928452182,
#          'while': 0.01303760235312823,
#          'months': 0.01303760235312823,
#          'domestic': 0.01303760235312823,
#          'around': 0.01303760235312823,
#          'shrs': 0.01303760235312823,
#          'earlier': 0.012878607202480324,
#          'assets': 0.012878607202480324,
#          'sources': 0.012799109627156371,
#          'yesterday': 0.012799109627156371,
#          'investment': 0.012799109627156371,
#          'due': 0.012719612051832418,
#          'crude': 0.012719612051832418,
#          'years': 0.012640114476508467,
#          'supply': 0.012560616901184514,
#          'gas': 0.012560616901184514,
#          'average': 0.012560616901184514,
#          'since': 0.012560616901184514,
#          'reported': 0.012481119325860561,
#          'period': 0.012481119325860561,
#          'surplus': 0.012322124175212655,
#          'agreed': 0.012322124175212655,
#          'next': 0.012322124175212655,
#          'compared': 0.012322124175212655,
#          'p': 0.012322124175212655,
#          'reserves': 0.012163129024564751,
#          'canada': 0.012163129024564751,
#          'currency': 0.012163129024564751,
#          'export': 0.012083631449240798,
#          'lower': 0.012083631449240798,
#          'buy': 0.012083631449240798,
#          'pay': 0.012004133873916845,
#          'securities': 0.012004133873916845,
#          'common': 0.012004133873916845,
#          'high': 0.011924636298592892,
#          'banks': 0.011845138723268941,
#          'financial': 0.011765641147944988,
#          'out': 0.011765641147944988,
#          'policy': 0.011765641147944988,
#          'stake': 0.011765641147944988,
#          'plan': 0.011765641147944988,
#          'seven': 0.011686143572621035,
#          'sale': 0.011686143572621035,
#          'tender': 0.011686143572621035,
#          'should': 0.011606645997297082,
#          'time': 0.01152714842197313,
#          'chairman': 0.01152714842197313,
#          'states': 0.01152714842197313,
#          'federal': 0.01152714842197313,
#          'shareholders': 0.01152714842197313,
#          'canadian': 0.01152714842197313,
#          'ended': 0.011447650846649178,
#          'says': 0.011368153271325225,
#          'any': 0.011288655696001272,
#          'countries': 0.011288655696001272,
#          'based': 0.011288655696001272,
#          'trading': 0.01120915812067732,
#          'before': 0.01120915812067732,
#          'sell': 0.011050162970029415,
#          'down': 0.010970665394705462,
#          'i': 0.010970665394705462,
#          'however': 0.010891167819381509,
#          'president': 0.010891167819381509,
#          'bid': 0.010891167819381509,
#          'dividend': 0.010811670244057556,
#          'dome': 0.010811670244057556,
#          'south': 0.010732172668733603,
#          'credit': 0.010732172668733603,
#          'debt': 0.010732172668733603,
#          'take': 0.01065267509340965,
#          'traders': 0.010573177518085699,
#          'day': 0.010493679942761746,
#          'subsidiary': 0.010493679942761746,
#          'grain': 0.01033468479211384,
#          'sugar': 0.01033468479211384,
#          'agriculture': 0.01033468479211384,
#          'operations': 0.01033468479211384,
#          'crop': 0.01033468479211384,
#          'ago': 0.010255187216789887,
#          'days': 0.010175689641465936,
#          'merger': 0.010175689641465936,
#          'includes': 0.010096192066141983,
#          'announced': 0.010096192066141983,
#          'american': 0.01001669449081803,
#          'fell': 0.01001669449081803,
#          'economy': 0.009937196915494077,
#          'owned': 0.009937196915494077,
#          'dealers': 0.009937196915494077,
#          'did': 0.009778201764846173,
#          'income': 0.009778201764846173,
#          'minister': 0.00969870418952222,
#          'management': 0.00969870418952222,
#          'european': 0.009619206614198267,
#          'acquire': 0.009619206614198267,
#          'term': 0.009539709038874314,
#          'industrial': 0.009539709038874314,
#          'through': 0.009539709038874314,
#          'long': 0.009460211463550361,
#          'each': 0.009460211463550361,
#          'use': 0.009460211463550361,
#          'figures': 0.00938071388822641,
#          'loans': 0.00938071388822641,
#          'industries': 0.00938071388822641,
#          'budget': 0.009301216312902457,
#          'monetary': 0.009301216312902457,
#          'can': 0.009221718737578504,
#          'loan': 0.009221718737578504,
#          't': 0.00914222116225455,
#          'firm': 0.009062723586930598,
#          'prior': 0.009062723586930598,
#          'oper': 0.009062723586930598,
#          'half': 0.008983226011606647,
#          'capital': 0.008983226011606647,
#          'talks': 0.008903728436282694,
#          'still': 0.008903728436282694,
#          'state': 0.008903728436282694,
#          'finance': 0.008903728436282694,
#          'fall': 0.00882423086095874,
#          'commission': 0.00882423086095874,
#          'nine': 0.00882423086095874,
#          'terms': 0.00882423086095874,
#          'during': 0.008744733285634788,
#          'plans': 0.008744733285634788,
#          'july': 0.008744733285634788,
#          'reserve': 0.008665235710310835,
#          'ministry': 0.008585738134986884,
#          'most': 0.008585738134986884,
#          'usda': 0.008585738134986884,
#          'held': 0.008585738134986884,
#          'output': 0.00850624055966293,
#          'acquired': 0.00850624055966293,
#          'proposed': 0.008426742984338978,
#          'china': 0.008426742984338978,
#          'value': 0.008426742984338978,
#          'likely': 0.008426742984338978,
#          'january': 0.008426742984338978,
#          'purchase': 0.008426742984338978,
#          'estimated': 0.008347245409015025,
#          'his': 0.008347245409015025,
#          'country': 0.00818825025836712,
#          'so': 0.00818825025836712,
#          'k': 0.00818825025836712,
#          'non': 0.00818825025836712,
#          'union': 0.00818825025836712,
#          'recent': 0.008108752683043167,
#          'system': 0.008108752683043167,
#          'inflation': 0.008108752683043167,
#          'data': 0.008108752683043167,
#          'outstanding': 0.008108752683043167,
#          'move': 0.008029255107719215,
#          'gain': 0.008029255107719215,
#          'our': 0.008029255107719215,
#          'including': 0.008029255107719215,
#          'annual': 0.008029255107719215,
#          'sold': 0.008029255107719215,
#          'such': 0.007949757532395262,
#          'start': 0.007949757532395262,
#          'eight': 0.007949757532395262,
#          'gold': 0.007870259957071309,
#          'german': 0.007870259957071309,
#          'who': 0.0077907623817473565,
#          'open': 0.0077907623817473565,
#          'expects': 0.0077907623817473565,
#          'corn': 0.0077907623817473565,
#          'plc': 0.0077907623817473565,
#          'being': 0.007711264806423404,
#          'say': 0.007711264806423404,
#          'lead': 0.0076317672310994514,
#          'forecast': 0.0076317672310994514,
#          'part': 0.0076317672310994514,
#          'level': 0.0076317672310994514,
#          'operating': 0.0075522696557754985,
#          'full': 0.0075522696557754985,
#          'energy': 0.007393274505127593,
#          'reagan': 0.007393274505127593,
#          'much': 0.007313776929803641,
#          'washington': 0.007313776929803641,
#          'reuters': 0.007313776929803641,
#          'results': 0.007313776929803641,
#          'previously': 0.007313776929803641,
#          'gulf': 0.007313776929803641,
#          'adjusted': 0.007313776929803641,
#          'make': 0.007234279354479688,
#          'effective': 0.007234279354479688,
#          'less': 0.007234279354479688,
#          'both': 0.007234279354479688,
#          'do': 0.007154781779155735,
#          'fiscal': 0.007154781779155735,
#          'well': 0.007154781779155735,
#          'levels': 0.007154781779155735,
#          'n': 0.007154781779155735,
#          'set': 0.007154781779155735,
#          'off': 0.007075284203831783,
#          'development': 0.007075284203831783,
#          'december': 0.007075284203831783,
#          'another': 0.007075284203831783,
#          'm': 0.007075284203831783,
#          'petroleum': 0.007075284203831783,
#          'same': 0.00699578662850783,
#          'york': 0.00699578662850783,
#          'proposal': 0.00699578662850783,
#          'takeover': 0.00699578662850783,
#          'texas': 0.00699578662850783,
#          'short': 0.006916289053183878,
#          'these': 0.006916289053183878,
#          'farm': 0.006916289053183878,
#          'cents': 0.006916289053183878,
#          'consumer': 0.006916289053183878,
#          'house': 0.006916289053183878,
#          'computer': 0.006916289053183878,
#          'cost': 0.006836791477859925,
#          'general': 0.006836791477859925,
#          'result': 0.006836791477859925,
#          'issue': 0.006757293902535972,
#          'previous': 0.006757293902535972,
#          'bought': 0.006757293902535972,
#          'strong': 0.006757293902535972,
#          'mths': 0.006757293902535972,
#          'continue': 0.00667779632721202,
#          'public': 0.00667779632721202,
#          'bundesbank': 0.00667779632721202,
#          'profits': 0.00667779632721202,
#          'account': 0.00667779632721202,
#          'barrel': 0.00667779632721202,
#          'cuts': 0.00667779632721202,
#          'increased': 0.006598298751888067,
#          'g': 0.006598298751888067,
#          'tariffs': 0.006518801176564115,
#          'action': 0.006518801176564115,
#          'second': 0.006518801176564115,
#          'several': 0.006518801176564115,
#          'already': 0.006518801176564115,
#          'marks': 0.006518801176564115,
#          'div': 0.006518801176564115,
#          'free': 0.006518801176564115,
#          'intervention': 0.006439303601240162,
#          'help': 0.006359806025916209,
#          'change': 0.006359806025916209,
#          'germany': 0.006359806025916209,
#          'british': 0.006359806025916209,
#          'largest': 0.006280308450592257,
#          'opec': 0.006280308450592257,
#          'revenues': 0.006280308450592257,
#          'soybean': 0.006200810875268304,
#          'contract': 0.006200810875268304,
#          'reduce': 0.006121313299944352,
#          'what': 0.006121313299944352,
#          'sees': 0.006041815724620399,
#          'c': 0.006041815724620399,
#          'early': 0.006041815724620399,
#          'amount': 0.006041815724620399,
#          'tokyo': 0.005962318149296446,
#          'those': 0.005962318149296446,
#          'following': 0.005962318149296446,
#          'tonne': 0.005962318149296446,
#          'low': 0.005962318149296446,
#          'pipeline': 0.005962318149296446,
#          'asked': 0.005882820573972494,
#          'decline': 0.005882820573972494,
#          'committee': 0.005882820573972494,
#          'losses': 0.005882820573972494,
#          'services': 0.005882820573972494,
#          'split': 0.005882820573972494,
#          'chemical': 0.005882820573972494,
#          'paris': 0.005882820573972494,
#          'e': 0.005882820573972494,
#          'preferred': 0.005882820573972494,
#          'prime': 0.005803322998648541,
#          'rising': 0.005803322998648541,
#          'making': 0.005803322998648541,
#          'funds': 0.005803322998648541,
#          'weeks': 0.005803322998648541,
#          'product': 0.005803322998648541,
#          'season': 0.005803322998648541,
#          'deposits': 0.005803322998648541,
#          'subject': 0.005723825423324589,
#          'possible': 0.005723825423324589,
#          'producers': 0.005723825423324589,
#          'very': 0.005723825423324589,
#          'rice': 0.005723825423324589,
#          'marketing': 0.005723825423324589,
#          'community': 0.005723825423324589,
#          'nations': 0.005644327848000636,
#          'despite': 0.005644327848000636,
#          'coffee': 0.005644327848000636,
#          'good': 0.005644327848000636,
#          'support': 0.005644327848000636,
#          'fund': 0.005644327848000636,
#          'raised': 0.005564830272676683,
#          'large': 0.005564830272676683,
#          'decision': 0.005564830272676683,
#          'basis': 0.005564830272676683,
#          'bill': 0.005564830272676683,
#          'copper': 0.005564830272676683,
#          'burlington': 0.005564830272676683,
#          'goods': 0.005485332697352731,
#          'brazil': 0.005485332697352731,
#          'texaco': 0.005485332697352731,
#          'western': 0.005405835122028778,
#          'line': 0.005405835122028778,
#          'given': 0.005405835122028778,
#          'own': 0.005405835122028778,
#          'received': 0.005405835122028778,
#          'court': 0.005405835122028778,
#          'costs': 0.005405835122028778,
#          'import': 0.005326337546704825,
#          'third': 0.005326337546704825,
#          'measures': 0.005326337546704825,
#          'position': 0.005326337546704825,
#          'here': 0.005326337546704825,
#          'does': 0.005326337546704825,
#          'transaction': 0.005326337546704825,
#          'french': 0.005326337546704825,
#          'completed': 0.005326337546704825,
#          'raises': 0.005326337546704825,
#          'below': 0.005246839971380873,
#          'program': 0.005246839971380873,
#          'although': 0.005246839971380873,
#          'latest': 0.005246839971380873,
#          'plant': 0.005246839971380873,
#          'seen': 0.005246839971380873,
#          'l': 0.005246839971380873,
#          'used': 0.005246839971380873,
#          'balance': 0.005246839971380873,
#          'cocoa': 0.005246839971380873,
#          'x': 0.005246839971380873,
#          'include': 0.00516734239605692,
#          'daily': 0.00516734239605692,
#          'approval': 0.00516734239605692,
#          'paid': 0.00516734239605692,
#          'b': 0.00516734239605692,
#          'savings': 0.00516734239605692,
#          'discount': 0.00516734239605692,
#          'futures': 0.005087844820732968,
#          'approved': 0.005087844820732968,
#          'number': 0.005087844820732968,
#          'little': 0.005087844820732968,
#          'london': 0.005087844820732968,
#          'reached': 0.005087844820732968,
#          'th': 0.005087844820732968,
#          'meet': 0.005008347245409015,
#          'certain': 0.005008347245409015,
#          'within': 0.005008347245409015,
#          'available': 0.005008347245409015,
#          'francs': 0.005008347245409015,
#          'above': 0.005008347245409015,
#          'sets': 0.005008347245409015,
#          'raise': 0.005008347245409015,
#          'lynch': 0.005008347245409015,
#          'estimates': 0.004928849670085062,
#          'taiwan': 0.004928849670085062,
#          'called': 0.004928849670085062,
#          'until': 0.004928849670085062,
#          'show': 0.004928849670085062,
#          'past': 0.004928849670085062,
#          'close': 0.004928849670085062,
#          'nd': 0.004928849670085062,
#          'noted': 0.00484935209476111,
#          'declined': 0.00484935209476111,
#          'area': 0.00484935209476111,
#          'rights': 0.00484935209476111,
#          'france': 0.00484935209476111,
#          'analyst': 0.004769854519437157,
#          'where': 0.004769854519437157,
#          'supplies': 0.004769854519437157,
#          'accord': 0.004769854519437157,
#          'range': 0.004769854519437157,
#          'unchanged': 0.004769854519437157,
#          'buying': 0.004769854519437157,
#          'might': 0.004690356944113205,
#          'pact': 0.004690356944113205,
#          'put': 0.004690356944113205,
#          'producer': 0.004690356944113205,
#          'investors': 0.004690356944113205,
#          'payments': 0.004690356944113205,
#          'insurance': 0.004690356944113205,
#          'merrill': 0.004690356944113205,
#          'them': 0.004610859368789252,
#          'delivery': 0.004610859368789252,
#          'council': 0.004610859368789252,
#          'see': 0.004610859368789252,
#          'bankers': 0.004610859368789252,
#          'economists': 0.004610859368789252,
#          'special': 0.004610859368789252,
#          'firms': 0.004531361793465299,
#          'pressure': 0.004531361793465299,
#          'partners': 0.004531361793465299,
#          'beef': 0.004531361793465299,
#          'details': 0.004531361793465299,
#          'currently': 0.004531361793465299,
#          'name': 0.004531361793465299,
#          'control': 0.004531361793465299,
#          'deal': 0.004531361793465299,
#          'private': 0.004531361793465299,
#          'ministers': 0.004531361793465299,
#          'yield': 0.004531361793465299,
#          'australian': 0.004451864218141347,
#          'holdings': 0.004451864218141347,
#          'trust': 0.004451864218141347,
#          'drop': 0.004451864218141347,
#          'treasury': 0.004451864218141347,
#          'just': 0.004451864218141347,
#          'financing': 0.004451864218141347,
#          'systems': 0.004451864218141347,
#          'warner': 0.004451864218141347,
#          'far': 0.004372366642817394,
#          'remain': 0.004372366642817394,
#          'problems': 0.004372366642817394,
#          'australia': 0.004372366642817394,
#          'later': 0.004372366642817394,
#          'joint': 0.004372366642817394,
#          'holding': 0.004372366642817394,
#          'bills': 0.004372366642817394,
#          'planned': 0.004372366642817394,
#          'point': 0.004372366642817394,
#          'executive': 0.004372366642817394,
#          'comment': 0.004372366642817394,
#          'steel': 0.004372366642817394,
#          'soviet': 0.004372366642817394,
#          'qtly': 0.004372366642817394,
#          'feb': 0.004372366642817394,
#          'agreements': 0.004372366642817394,
#          'currencies': 0.004372366642817394,
#          'many': 0.004292869067493442,
#          'spending': 0.004292869067493442,
#          'according': 0.004292869067493442,
#          'workers': 0.004292869067493442,
#          'banking': 0.004292869067493442,
#          'target': 0.004292869067493442,
#          'sector': 0.004292869067493442,
#          'september': 0.004292869067493442,
#          'barrels': 0.004292869067493442,
#          'continued': 0.004292869067493442,
#          'borg': 0.004292869067493442,
#          'association': 0.004213371492169489,
#          'local': 0.004213371492169489,
#          'october': 0.004213371492169489,
#          'too': 0.004213371492169489,
#          'america': 0.004213371492169489,
#          'probably': 0.004213371492169489,
#          'stability': 0.004213371492169489,
#          'field': 0.004213371492169489,
#          'without': 0.004213371492169489,
#          'date': 0.004213371492169489,
#          'transcanada': 0.004213371492169489,
#          'oecd': 0.004213371492169489,
#          'exporters': 0.004133873916845536,
#          'impact': 0.004133873916845536,
#          'food': 0.004133873916845536,
#          'f': 0.004133873916845536,
#          'east': 0.004133873916845536,
#          'whether': 0.004133873916845536,
#          'britain': 0.004133873916845536,
#          'units': 0.004133873916845536,
#          'dollars': 0.004133873916845536,
#          'bpd': 0.004133873916845536,
#          'news': 0.004133873916845536,
#          'prev': 0.004133873916845536,
#          'chief': 0.004054376341521584,
#          'key': 0.004054376341521584,
#          'tin': 0.004054376341521584,
#          'worth': 0.004054376341521584,
#          'future': 0.004054376341521584,
#          'continuing': 0.004054376341521584,
#          'late': 0.004054376341521584,
#          'conditions': 0.004054376341521584,
#          'offered': 0.004054376341521584,
#          'think': 0.004054376341521584,
#          'figure': 0.004054376341521584,
#          'division': 0.004054376341521584,
#          'yet': 0.004054376341521584,
#          'harcourt': 0.004054376341521584,
#          'natural': 0.003974878766197631,
#          'port': 0.003974878766197631,
#          'needed': 0.003974878766197631,
#          'mine': 0.003974878766197631,
#          'back': 0.003974878766197631,
#          'bond': 0.003974878766197631,
#          'restructuring': 0.003974878766197631,
#          'exploration': 0.003974878766197631,
#          'get': 0.003974878766197631,
#          'dutch': 0.003974878766197631,
#          'leading': 0.0038953811908736783,
#          'korea': 0.0038953811908736783,
#          'commodity': 0.0038953811908736783,
#          'need': 0.0038953811908736783,
#          'expect': 0.0038953811908736783,
#          'businesses': 0.0038953811908736783,
#          'members': 0.0038953811908736783,
#          'repurchase': 0.0038953811908736783,
#          'give': 0.0038953811908736783,
#          'secretary': 0.0038953811908736783,
#          'pretax': 0.0038953811908736783,
#          'saudi': 0.0038953811908736783,
#          'congress': 0.0038953811908736783,
#          'saying': 0.0038953811908736783,
#          'receive': 0.0038953811908736783,
#          'reduced': 0.0038953811908736783,
#          'cotton': 0.0038953811908736783,
#          'wk': 0.0038953811908736783,
#          'showed': 0.0038158836155497257,
#          'ending': 0.0038158836155497257,
#          'taken': 0.0038158836155497257,
#          'real': 0.0038158836155497257,
#          'issued': 0.0038158836155497257,
#          'mark': 0.0038158836155497257,
#          'announcement': 0.0038158836155497257,
#          'increases': 0.0038158836155497257,
#          'undisclosed': 0.0038158836155497257,
#          'reporters': 0.003736386040225773,
#          'fixed': 0.003736386040225773,
#          'manufacturing': 0.003736386040225773,
#          'heavy': 0.003736386040225773,
#          'recently': 0.003736386040225773,
#          'de': 0.003736386040225773,
#          'disclosed': 0.003736386040225773,
#          'communique': 0.003736386040225773,
#          'administration': 0.003736386040225773,
#          'must': 0.0036568884649018207,
#          'indonesia': 0.0036568884649018207,
#          'sharply': 0.0036568884649018207,
#          'began': 0.0036568884649018207,
#          'venture': 0.0036568884649018207,
#          'farmers': 0.0036568884649018207,
#          'even': 0.0036568884649018207,
#          'research': 0.0036568884649018207,
#          'gaf': 0.0036568884649018207,
#          'gains': 0.0036568884649018207,
#          'boost': 0.0035773908895778677,
#          'produced': 0.0035773908895778677,
#          'follows': 0.0035773908895778677,
#          'revised': 0.0035773908895778677,
#          'materials': 0.0035773908895778677,
#          'effect': 0.0035773908895778677,
#          'least': 0.0035773908895778677,
#          'europe': 0.0035773908895778677,
#          'signed': 0.0035773908895778677,
#          'gasoline': 0.0035773908895778677,
#          'reduction': 0.0035773908895778677,
#          'information': 0.0035773908895778677,
#          'final': 0.0035773908895778677,
#          'rd': 0.0035773908895778677,
#          'investor': 0.0035773908895778677,
#          'way': 0.0035773908895778677,
#          'soybeans': 0.0035773908895778677,
#          'filing': 0.0035773908895778677,
#          'among': 0.003497893314253915,
#          'office': 0.003497893314253915,
#          'friday': 0.003497893314253915,
#          'gave': 0.003497893314253915,
#          'main': 0.003497893314253915,
#          'conference': 0.003497893314253915,
#          're': 0.003497893314253915,
#          'index': 0.003497893314253915,
#          'j': 0.003497893314253915,
#          'payable': 0.003497893314253915,
#          'fourth': 0.003497893314253915,
#          'want': 0.0034183957389299626,
#          'changes': 0.0034183957389299626,
#          'resources': 0.0034183957389299626,
#          'go': 0.0034183957389299626,
#          'home': 0.0034183957389299626,
#          'manager': 0.0034183957389299626,
#          'become': 0.0034183957389299626,
#          'addition': 0.0034183957389299626,
#          'hold': 0.0034183957389299626,
#          'owns': 0.0034183957389299626,
#          'areas': 0.0034183957389299626,
#          'north': 0.0034183957389299626,
#          'series': 0.0034183957389299626,
#          'shipments': 0.0034183957389299626,
#          'offers': 0.0034183957389299626,
#          'buys': 0.0034183957389299626,
#          'additional': 0.0034183957389299626,
#          'smelter': 0.0034183957389299626,
#          'spot': 0.0034183957389299626,
#          'few': 0.00333889816360601,
#          'selling': 0.00333889816360601,
#          'then': 0.00333889816360601,
#          'contracts': 0.00333889816360601,
#          'building': 0.00333889816360601,
#          'capacity': 0.00333889816360601,
#          'rises': 0.00333889816360601,
#          'growing': 0.00333889816360601,
#          'scheduled': 0.00333889816360601,
#          'sharp': 0.00333889816360601,
#          'strike': 0.00333889816360601,
#          'service': 0.00333889816360601,
#          'associates': 0.00333889816360601,
#          'credits': 0.00333889816360601,
#          'present': 0.00333889816360601,
#          'stores': 0.00333889816360601,
#          'tons': 0.00333889816360601,
#          'us': 0.0032594005882820576,
#          'commercial': 0.0032594005882820576,
#          'director': 0.0032594005882820576,
#          'improved': 0.0032594005882820576,
#          'maize': 0.0032594005882820576,
#          'better': 0.0032594005882820576,
#          'how': 0.0032594005882820576,
#          'near': 0.0032594005882820576,
#          'believe': 0.0032594005882820576,
#          'provide': 0.0032594005882820576,
#          'interests': 0.0032594005882820576,
#          'gnp': 0.0032594005882820576,
#          'seeking': 0.0032594005882820576,
#          'white': 0.0032594005882820576,
#          'd': 0.0032594005882820576,
#          'tomorrow': 0.0032594005882820576,
#          'slightly': 0.0032594005882820576,
#          'guilders': 0.0032594005882820576,
#          'bancorp': 0.0032594005882820576,
#          'monthly': 0.0032594005882820576,
#          'borrowings': 0.0032594005882820576,
#          'senior': 0.0031799030129581046,
#          'allow': 0.0031799030129581046,
#          'view': 0.0031799030129581046,
#          'technology': 0.0031799030129581046,
#          'work': 0.0031799030129581046,
#          'mining': 0.0031799030129581046,
#          'small': 0.0031799030129581046,
#          'swiss': 0.0031799030129581046,
#          'don': 0.0031799030129581046,
#          'security': 0.0031799030129581046,
#          'equity': 0.0031799030129581046,
#          'mainly': 0.0031799030129581046,
#          'top': 0.0031799030129581046,
#          'press': 0.0031799030129581046,
#          'substantial': 0.0031799030129581046,
#          'believed': 0.0031799030129581046,
#          'adding': 0.0031799030129581046,
#          'keep': 0.0031799030129581046,
#          'unemployment': 0.0031799030129581046,
#          'provision': 0.0031799030129581046,
#          'commerce': 0.0031799030129581046,
#          'speculation': 0.0031799030129581046,
#          'force': 0.0031799030129581046,
#          'wednesday': 0.0031799030129581046,
#          'eddie': 0.0031799030129581046,
#          'bbl': 0.0031799030129581046,
#          'concern': 0.003100405437634152,
#          'august': 0.003100405437634152,
#          'affected': 0.003100405437634152,
#          'pacific': 0.003100405437634152,
#          'led': 0.003100405437634152,
#          'payment': 0.003100405437634152,
#          'equipment': 0.003100405437634152,
#          'acquisitions': 0.003100405437634152,
#          'charge': 0.003100405437634152,
#          'africa': 0.003100405437634152,
#          'ccc': 0.003100405437634152,
#          'crazy': 0.003100405437634152,
#          'named': 0.0030209078623101996,
#          'agency': 0.0030209078623101996,
#          'taking': 0.0030209078623101996,
#          'city': 0.0030209078623101996,
#          'people': 0.0030209078623101996,
#          'base': 0.0030209078623101996,
#          'england': 0.0030209078623101996,
#          'gross': 0.0030209078623101996,
#          'iraq': 0.0030209078623101996,
#          'quota': 0.0030209078623101996,
#          'morning': 0.0030209078623101996,
#          'statistics': 0.0030209078623101996,
#          'predicted': 0.0030209078623101996,
#          'payout': 0.0030209078623101996,
#          'return': 0.0030209078623101996,
#          'light': 0.0030209078623101996,
#          'hit': 0.002941410286986247,
#          'hard': 0.002941410286986247,
#          'maintain': 0.002941410286986247,
#          'like': 0.002941410286986247,
#          'negotiations': 0.002941410286986247,
#          'bonus': 0.002941410286986247,
#          'limit': 0.002941410286986247,
#          'overall': 0.002941410286986247,
#          'decided': 0.002941410286986247,
#          'san': 0.002941410286986247,
#          'standard': 0.002941410286986247,
#          'italy': 0.002941410286986247,
#          'metal': 0.002941410286986247,
#          'poehl': 0.002941410286986247,
#          'makes': 0.002941410286986247,
#          'letter': 0.002941410286986247,
#          'postings': 0.002941410286986247,
#          'gillette': 0.002941410286986247,
#          'similar': 0.0028619127116622945,
#          'review': 0.0028619127116622945,
#          'rubber': 0.0028619127116622945,
#          'ships': 0.0028619127116622945,
#          'moves': 0.0028619127116622945,
#          'soon': 0.0028619127116622945,
#          'rather': 0.0028619127116622945,
#          'almost': 0.0028619127116622945,
#          'add': 0.0028619127116622945,
#          'political': 0.0028619127116622945,
#          'situation': 0.0028619127116622945,
#          'imf': 0.0028619127116622945,
#          'baker': 0.0028619127116622945,
#          'dominion': 0.0028619127116622945,
#          'allied': 0.0028619127116622945,
#          'barley': 0.0028619127116622945,
#          'shell': 0.0028619127116622945,
#          'institutes': 0.0028619127116622945,
#          'electric': 0.0027824151363383415,
#          'slow': 0.0027824151363383415,
#          'spain': 0.0027824151363383415,
#          'included': 0.0027824151363383415,
#          'order': 0.0027824151363383415,
#          'economist': 0.0027824151363383415,
#          'kuwait': 0.0027824151363383415,
#          'monier': 0.0027824151363383415,
#          'expansion': 0.0027824151363383415,
#          'remaining': 0.0027824151363383415,
#          'begin': 0.0027824151363383415,
#          'seasonally': 0.0027824151363383415,
#          'cominco': 0.0027824151363383415,
#          'significant': 0.002702917561014389,
#          'party': 0.002702917561014389,
#          'package': 0.002702917561014389,
#          'nearly': 0.002702917561014389,
#          'limited': 0.002702917561014389,
#          'octane': 0.002702917561014389,
#          'buyers': 0.002702917561014389,
#          'quoted': 0.002702917561014389,
#          'response': 0.002702917561014389,
#          'caused': 0.002702917561014389,
#          'newspaper': 0.002702917561014389,
#          'saw': 0.002702917561014389,
#          'morgan': 0.002702917561014389,
#          'meal': 0.002702917561014389,
#          'she': 0.002702917561014389,
#          'orange': 0.002702917561014389,
#          'lawson': 0.002702917561014389,
#          'commitments': 0.002702917561014389,
#          'csr': 0.002702917561014389,
#          'stcks': 0.002702917561014389,
#          'james': 0.0026234199856904365,
#          'crops': 0.0026234199856904365,
#          'purchases': 0.0026234199856904365,
#          'right': 0.0026234199856904365,
#          'bids': 0.0026234199856904365,
#          'started': 0.0026234199856904365,
#          'properties': 0.0026234199856904365,
#          'pre': 0.0026234199856904365,
#          'life': 0.0026234199856904365,
#          'turnover': 0.0026234199856904365,
#          'head': 0.0026234199856904365,
#          'cooperation': 0.0026234199856904365,
#          'stable': 0.0026234199856904365,
#          'sells': 0.0026234199856904365,
#          'zealand': 0.0026234199856904365,
#          'opened': 0.0026234199856904365,
#          'directors': 0.0026234199856904365,
#          'again': 0.0026234199856904365,
#          'revenue': 0.0026234199856904365,
#          'initial': 0.0026234199856904365,
#          'offset': 0.0026234199856904365,
#          'louvre': 0.0026234199856904365,
#          'ldp': 0.0026234199856904365,
#          'independent': 0.0026234199856904365,
#          'excludes': 0.0026234199856904365,
#          'buyout': 0.0026234199856904365,
#          'buffer': 0.0026234199856904365,
#          'meat': 0.0026234199856904365,
#          'consumers': 0.0026234199856904365,
#          'textile': 0.002543922410366484,
#          'palm': 0.002543922410366484,
#          'considering': 0.002543922410366484,
#          'plus': 0.002543922410366484,
#          'shipment': 0.002543922410366484,
#          'entered': 0.002543922410366484,
#          'act': 0.002543922410366484,
#          'holds': 0.002543922410366484,
#          'quotas': 0.002543922410366484,
#          'potential': 0.002543922410366484,
#          'particularly': 0.002543922410366484,
#          'corporation': 0.002543922410366484,
#          'arabia': 0.002543922410366484,
#          'lost': 0.002543922410366484,
#          'calls': 0.002543922410366484,
#          'estimate': 0.002543922410366484,
#          'form': 0.002543922410366484,
#          'increasing': 0.002543922410366484,
#          'senate': 0.002543922410366484,
#          'working': 0.002543922410366484,
#          'privately': 0.002543922410366484,
#          'round': 0.002543922410366484,
#          'ecuador': 0.002543922410366484,
#          'policies': 0.002543922410366484,
#          'summit': 0.002543922410366484,
#          'feed': 0.002543922410366484,
#          'oils': 0.002543922410366484,
#          'able': 0.002464424835042531,
#          'place': 0.002464424835042531,
#          'reform': 0.002464424835042531,
#          'effort': 0.002464424835042531,
#          'factors': 0.002464424835042531,
#          'reflect': 0.002464424835042531,
#          'consolidated': 0.002464424835042531,
#          'war': 0.002464424835042531,
#          'institute': 0.002464424835042531,
#          'operate': 0.002464424835042531,
#          'sanctions': 0.002464424835042531,
#          'singapore': 0.002464424835042531,
#          'reason': 0.002464424835042531,
#          'november': 0.002464424835042531,
#          'discussions': 0.002464424835042531,
#          'process': 0.002464424835042531,
#          'lire': 0.002464424835042531,
#          'quarterly': 0.002464424835042531,
#          'diluted': 0.002464424835042531,
#          'immediately': 0.002464424835042531,
#          'communications': 0.002464424835042531,
#          'definitive': 0.002464424835042531,
#          'ct': 0.002464424835042531,
#          'projected': 0.002464424835042531,
#          'customers': 0.002464424835042531,
#          ...})

# %%
# Let's transform the counts to probabilities
for w1_w2 in model:
    total_count = float(sum(model[w1_w2].values()))
    for w3 in model[w1_w2]:
        model[w1_w2][w3] /= total_count

# %%
# predict the next word
dict(model["asian", "exporters"])
# Out:
# {'fear': 1.0}

# %%
#df['trigrams']
